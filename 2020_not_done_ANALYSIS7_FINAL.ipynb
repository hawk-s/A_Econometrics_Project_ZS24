# %% [markdown]
# # Analysis part - Blastoise___Holo_1999_Base_Set

# %%
library(ggplot2)
library(quantreg)


df = read.csv('lagged_merged_datasets_final/merged_Full_Art_Charizard_Vmax_Secret__Holo_2020_Champions_Path.csv')

#convert prices to returns
grades <- grep("grade[0-9]+price", names(df), value = TRUE)
grade_returns <- sapply(grades, function(x) paste0(x, "_return"))

for(grade in grades) {
  df[paste(grade, "return", sep = "_")] <- c(NA, diff(log(df[[grade]])))
}

# Convert adjclosestock and adjclosebond (including their lags) to returns
stock_bond_cols <- grep("adjclose(stock|bond)(lag[0-9]+)?", names(df), value = TRUE)

for(col in stock_bond_cols) {
  df[paste0(col, "_return")] <- c(NA, diff(log(df[[col]])))
}

# Remove rows with NA in the newly created return columns
df <- na.omit(df)

head(df)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Warning message:
# "package 'quantreg' was built under R version 3.6.3"Loading required package: SparseM
# Warning message:
# "package 'SparseM' was built under R version 3.6.3"
# Attaching package: 'SparseM'
#
# The following object is masked from 'package:base':
#
#     backsolve
#   date       grade9price grade10price adjclosestock volume       adjclosebond
# 2 2020-11-01 517.2866    1003.0225    3621.63       101247180000 1.573
# 3 2020-12-01 375.0000     731.6890    3756.07        96375680000 1.646
# 4 2021-01-01 393.1835     699.8251    3714.24       106117800000 1.858
# 5 2021-02-01 394.7493     682.4419    3811.15        99082320000 2.182
# 6 2021-03-01 343.8209     734.0345    3972.89       122371150000 2.425
# 7 2021-04-01 343.8209     734.0345    4181.17        83124090000 2.301
#   stockreturns bondadjusted excessreturns adjclosestocklag1 ...
# 2  0.10754564  0.01573       0.148399314  3269.96           ...
# 3  0.03712146  0.01646      -0.009286726  3621.63           ...
# 4 -0.01113666  0.01858      -0.139933750  3756.07           ...
# 5  0.02609145  0.02182      -0.148289536  3714.24           ...
# 6  0.04243863  0.02425      -0.068927105  3811.15           ...
# 7  0.05242532  0.02301       0.103559275  3972.89           ...
#   adjclosestocklag2_return adjclosebondlag2_return adjclosestocklag3_return
# 2 -0.04001812              -0.0006889747            0.06771908
# 3 -0.02805569               0.1224432763           -0.04001812
# 4  0.10214643              -0.0417116381           -0.02805569
# 5  0.03644905               0.0453635241            0.10214643
# 6 -0.01119914               0.1211525429            0.03644905
# 7  0.02575688               0.1607411896           -0.01119914
#   adjclosebondlag3_return adjclosestocklag4_return adjclosebondlag4_return
# 2  0.1922884700            0.05363680              -0.1622267992
# 3 -0.0006889747            0.06771908               0.1922884700
# 4  0.1224432763           -0.04001812              -0.0006889747
# 5 -0.0417116381           -0.02805569               0.1224432763
# 6  0.0453635241            0.10214643              -0.0417116381
# 7  0.1211525429            0.03644905               0.0453635241
#   adjclosestocklag5_return adjclosebondlag5_return adjclosestocklag6_return
# 2  0.01822137               0.0014205212            0.04428653
# 3  0.05363680              -0.1622267992            0.01822137
# 4  0.06771908               0.1922884700            0.05363680
# 5 -0.04001812              -0.0006889747            0.06771908
# 6 -0.02805569               0.1224432763           -0.04001812
# 7  0.10214643              -0.0417116381           -0.02805569
#   adjclosebondlag6_return
# 2  0.1055973902
# 3  0.0014205212
# 4 -0.1622267992
# 5  0.1922884700
# 6 -0.0006889747
# 7  0.1224432763

# %%
createReturnsCorrelationMatrix <- function(df) {
  # Load necessary libraries
  library(ggplot2)
  library(reshape2)
  
  # Use a simplified pattern to include both "_return" columns and any "volume" columns
  pattern <- "_return|volume"
  selected_columns <- grep(pattern, names(df), value = TRUE)
  
  # Calculate the correlation matrix for the selected columns
  correlation_matrix <- cor(df[, selected_columns], use = "complete.obs")
  
  # Print the correlation matrix to the console
  print(correlation_matrix)
  
  # Melt the correlation matrix for visualization
  melted_correlation_matrix <- melt(correlation_matrix)
  
  # Create the ggplot object for the correlation matrix
  plot <- ggplot(data = melted_correlation_matrix, aes(x=Var1, y=Var2, fill=value)) +
    geom_tile() +
    scale_fill_gradient2(midpoint=0, low="blue", high="red", mid="white") +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    labs(x='', y='', title='Correlation Matrix of Returns', fill='Correlation')
  
  # Explicitly print the ggplot object to ensure it's displayed
  print(plot)
  
  # Return the correlation matrix as well
  return(correlation_matrix)
}

# Assuming your adjusted dataset is in 'df'
# Example usage:
correlation_matrix <- createReturnsCorrelationMatrix(df)
# Out:
#                               volume   volumelag1    volumelag2   volumelag3
# volume                    1.00000000  0.067789588  0.2574794847  0.273746825
# volumelag1                0.06778959  1.000000000  0.0395341237  0.252022132
# volumelag2                0.25747948  0.039534124  1.0000000000  0.019222556
# volumelag3                0.27374682  0.252022132  0.0192225563  1.000000000
# volumelag4               -0.05191245  0.252335394  0.2001166457 -0.009500445
# volumelag5                0.05168055 -0.068396186  0.2096755409  0.100777798
# volumelag6               -0.01513724  0.038597842 -0.0894402819  0.177932142
# grade9price_return        0.29210981 -0.325557289  0.1854365303  0.211638073
# grade10price_return       0.25664107 -0.012600558  0.0054774271  0.117138750
# adjclosestock_return      0.05113211  0.003617043  0.0737500199 -0.237037265
# adjclosebond_return       0.21178764  0.103745454  0.0544126648  0.009989075
# adjclosestocklag1_return -0.15795245  0.043549028 -0.0216064562  0.081672169
# adjclosebondlag1_return   0.42150458  0.212046758  0.1234981087  0.031409941
# adjclosestocklag2_return -0.06510005 -0.177226793 -0.0046125362 -0.014726285
# adjclosebondlag2_return   0.14320535  0.452439824  0.2698858142  0.148314196
# adjclosestocklag3_return -0.04759950 -0.079975410 -0.2035755639 -0.038883209
# adjclosebondlag3_return   0.24892507  0.130078236  0.4497947964  0.209390044
# adjclosestocklag4_return  0.04199861 -0.043749313 -0.0642701749 -0.215288639
# adjclosebondlag4_return  -0.16342199  0.246238790  0.1313805482  0.469571173
# adjclosestocklag5_return  0.07267295  0.062370818  0.0006347344 -0.054756829
# adjclosebondlag5_return   0.18129623 -0.169248382  0.2407358043  0.133320817
# adjclosestocklag6_return -0.27546176  0.066787121  0.0580037694 -0.017336168
# adjclosebondlag6_return   0.02885507  0.180539273 -0.1644490402  0.219119997
#                             volumelag4    volumelag5  volumelag6
# volume                   -0.0519124523  0.0516805533 -0.01513724
# volumelag1                0.2523353941 -0.0683961862  0.03859784
# volumelag2                0.2001166457  0.2096755409 -0.08944028
# volumelag3               -0.0095004453  0.1007777981  0.17793214
# volumelag4                1.0000000000  0.0007970309  0.09374750
# volumelag5                0.0007970309  1.0000000000  0.07117777
# volumelag6                0.0937474983  0.0711777672  1.00000000
# grade9price_return       -0.0054562091  0.0404714815 -0.09159198
# grade10price_return      -0.1640663664  0.0918586936 -0.12324095
# adjclosestock_return      0.1985574685  0.2922420944 -0.08381577
# adjclosebond_return      -0.1638350747 -0.3384382024 -0.01449960
# adjclosestocklag1_return -0.2751475240  0.1124683776  0.26384444
# adjclosebondlag1_return   0.0388469242 -0.0450200756 -0.29458125
# adjclosestocklag2_return  0.0272713944 -0.3317066986  0.07409126
# adjclosebondlag2_return   0.0743872192  0.0149656811 -0.04322500
# adjclosestocklag3_return -0.0253490898  0.1102670880 -0.29894681
# adjclosebondlag3_return   0.1708265144  0.2202915163  0.06737859
# adjclosestocklag4_return -0.0140393938  0.0508162554  0.13551994
# adjclosebondlag4_return   0.1848325969 -0.0333147796  0.14710561
# adjclosestocklag5_return -0.1786282618  0.0141003012  0.06809154
# adjclosebondlag5_return   0.4674624946  0.1347575067 -0.04472480
# adjclosestocklag6_return -0.0551750317 -0.1034421351  0.03018345
# adjclosebondlag6_return   0.1534325739  0.4789701049  0.15724715
#                          grade9price_return grade10price_return
# volume                          0.292109813         0.256641068
# volumelag1                     -0.325557289        -0.012600558
# volumelag2                      0.185436530         0.005477427
# volumelag3                      0.211638073         0.117138750
# volumelag4                     -0.005456209        -0.164066366
# volumelag5                      0.040471482         0.091858694
# volumelag6                     -0.091591982        -0.123240945
# grade9price_return              1.000000000         0.013111931
# grade10price_return             0.013111931         1.000000000
# adjclosestock_return           -0.109652380         0.231569168
# adjclosebond_return             0.124771342        -0.244563010
# adjclosestocklag1_return       -0.029251619        -0.309584343
# adjclosebondlag1_return         0.213399625         0.312153921
# adjclosestocklag2_return        0.118401828         0.118473720
# adjclosebondlag2_return        -0.094945804        -0.303475660
# adjclosestocklag3_return       -0.224407528         0.067972122
# adjclosebondlag3_return         0.260699393         0.089636066
# adjclosestocklag4_return        0.139163005        -0.153455358
# adjclosebondlag4_return        -0.008645858        -0.065990843
# adjclosestocklag5_return       -0.117547594         0.053083312
# adjclosebondlag5_return         0.193670794         0.062208891
# adjclosestocklag6_return       -0.299943645         0.122193831
# adjclosebondlag6_return        -0.115489047         0.018449414
#                          adjclosestock_return adjclosebond_return
# volume                           5.113211e-02         0.211787640
# volumelag1                       3.617043e-03         0.103745454
# volumelag2                       7.375002e-02         0.054412665
# volumelag3                      -2.370373e-01         0.009989075
# volumelag4                       1.985575e-01        -0.163835075
# volumelag5                       2.922421e-01        -0.338438202
# volumelag6                      -8.381577e-02        -0.014499605
# grade9price_return              -1.096524e-01         0.124771342
# grade10price_return              2.315692e-01        -0.244563010
# adjclosestock_return             1.000000e+00        -0.516620505
# adjclosebond_return             -5.166205e-01         1.000000000
# adjclosestocklag1_return        -2.510606e-01        -0.001061672
# adjclosebondlag1_return          1.144663e-01         0.233771333
# adjclosestocklag2_return        -4.860169e-02         0.041624521
# adjclosebondlag2_return         -7.353418e-05        -0.004549103
# adjclosestocklag3_return         2.049284e-01         0.001202724
# adjclosebondlag3_return          1.267738e-01        -0.203913770
# adjclosestocklag4_return         1.462955e-01        -0.171990620
# adjclosebondlag4_return         -1.918930e-01         0.093394832
# adjclosestocklag5_return         1.267689e-01        -0.077338631
# adjclosebondlag5_return         -1.389434e-01        -0.014176977
# adjclosestocklag6_return        -1.785063e-01         0.038973848
# adjclosebondlag6_return          2.077746e-01        -0.110490688
#                          adjclosestocklag1_return adjclosebondlag1_return
# volume                               -0.157952452              0.42150458
# volumelag1                            0.043549028              0.21204676
# volumelag2                           -0.021606456              0.12349811
# volumelag3                            0.081672169              0.03140994
# volumelag4                           -0.275147524              0.03884692
# volumelag5                            0.112468378             -0.04502008
# volumelag6                            0.263844435             -0.29458125
# grade9price_return                   -0.029251619              0.21339963
# grade10price_return                  -0.309584343              0.31215392
# adjclosestock_return                 -0.251060646              0.11446633
# adjclosebond_return                  -0.001061672              0.23377133
# adjclosestocklag1_return              1.000000000             -0.52271613
# adjclosebondlag1_return              -0.522716134              1.00000000
# adjclosestocklag2_return             -0.252120521             -0.01799665
# adjclosebondlag2_return               0.140482873              0.20798499
# adjclosestocklag3_return             -0.078020156              0.08312420
# adjclosebondlag3_return              -0.034788918              0.05630755
# adjclosestocklag4_return              0.193141224              0.02372793
# adjclosebondlag4_return               0.161549857             -0.25804370
# adjclosestocklag5_return              0.161492325             -0.17799895
# adjclosebondlag5_return              -0.190880712              0.08590696
# adjclosestocklag6_return              0.110578660             -0.05235064
# adjclosebondlag6_return              -0.150466443              0.01134732
#                          adjclosestocklag2_return adjclosebondlag2_return
# volume                               -0.065100050            1.432053e-01
# volumelag1                           -0.177226793            4.524398e-01
# volumelag2                           -0.004612536            2.698858e-01
# volumelag3                           -0.014726285            1.483142e-01
# volumelag4                            0.027271394            7.438722e-02
# volumelag5                           -0.331706699            1.496568e-02
# volumelag6                            0.074091264           -4.322500e-02
# grade9price_return                    0.118401828           -9.494580e-02
# grade10price_return                   0.118473720           -3.034757e-01
# adjclosestock_return                 -0.048601691           -7.353418e-05
# adjclosebond_return                   0.041624521           -4.549103e-03
# adjclosestocklag1_return             -0.252120521            1.404829e-01
# adjclosebondlag1_return              -0.017996654            2.079850e-01
# adjclosestocklag2_return              1.000000000           -4.888046e-01
# adjclosebondlag2_return              -0.488804565            1.000000e+00
# adjclosestocklag3_return             -0.295552678           -1.610574e-02
# adjclosebondlag3_return               0.088272344            1.723034e-01
# adjclosestocklag4_return             -0.087109889            6.193608e-02
# adjclosebondlag4_return               0.027707759            7.435073e-02
# adjclosestocklag5_return              0.225355764           -8.503987e-03
# adjclosebondlag5_return               0.160241456           -2.486448e-01
# adjclosestocklag6_return              0.139586786           -1.830035e-01
# adjclosebondlag6_return              -0.205839814            7.029549e-02
#                          adjclosestocklag3_return adjclosebondlag3_return
# volume                               -0.047599497              0.24892507
# volumelag1                           -0.079975410              0.13007824
# volumelag2                           -0.203575564              0.44979480
# volumelag3                           -0.038883209              0.20939004
# volumelag4                           -0.025349090              0.17082651
# volumelag5                            0.110267088              0.22029152
# volumelag6                           -0.298946810              0.06737859
# grade9price_return                   -0.224407528              0.26069939
# grade10price_return                   0.067972122              0.08963607
# adjclosestock_return                  0.204928443              0.12677383
# adjclosebond_return                   0.001202724             -0.20391377
# adjclosestocklag1_return             -0.078020156             -0.03478892
# adjclosebondlag1_return               0.083124198              0.05630755
# adjclosestocklag2_return             -0.295552678              0.08827234
# adjclosebondlag2_return              -0.016105737              0.17230339
# adjclosestocklag3_return              1.000000000             -0.38994888
# adjclosebondlag3_return              -0.389948877              1.00000000
# adjclosestocklag4_return             -0.255642282              0.02920009
# adjclosebondlag4_return               0.012200265              0.03251876
# adjclosestocklag5_return             -0.066671155              0.06407642
# adjclosebondlag5_return               0.013061645              0.05544690
# adjclosestocklag6_return              0.240605112              0.02960618
# adjclosebondlag6_return               0.186966030             -0.18704666
#                          adjclosestocklag4_return adjclosebondlag4_return
# volume                                0.041998607            -0.163421993
# volumelag1                           -0.043749313             0.246238790
# volumelag2                           -0.064270175             0.131380548
# volumelag3                           -0.215288639             0.469571173
# volumelag4                           -0.014039394             0.184832597
# volumelag5                            0.050816255            -0.033314780
# volumelag6                            0.135519941             0.147105607
# grade9price_return                    0.139163005            -0.008645858
# grade10price_return                  -0.153455358            -0.065990843
# adjclosestock_return                  0.146295498            -0.191892953
# adjclosebond_return                  -0.171990620             0.093394832
# adjclosestocklag1_return              0.193141224             0.161549857
# adjclosebondlag1_return               0.023727931            -0.258043703
# adjclosestocklag2_return             -0.087109889             0.027707759
# adjclosebondlag2_return               0.061936078             0.074350735
# adjclosestocklag3_return             -0.255642282             0.012200265
# adjclosebondlag3_return               0.029200093             0.032518765
# adjclosestocklag4_return              1.000000000            -0.413410826
# adjclosebondlag4_return              -0.413410826             1.000000000
# adjclosestocklag5_return             -0.265086992             0.013520856
# adjclosebondlag5_return               0.008604186             0.049668855
# adjclosestocklag6_return             -0.048137403             0.018396846
# adjclosebondlag6_return               0.030844998            -0.001892280
#                          adjclosestocklag5_return adjclosebondlag5_return
# volume                               0.0726729506             0.181296227
# volumelag1                           0.0623708184            -0.169248382
# volumelag2                           0.0006347344             0.240735804
# volumelag3                          -0.0547568292             0.133320817
# volumelag4                          -0.1786282618             0.467462495
# volumelag5                           0.0141003012             0.134757507
# volumelag6                           0.0680915437            -0.044724802
# grade9price_return                  -0.1175475943             0.193670794
# grade10price_return                  0.0530833118             0.062208891
# adjclosestock_return                 0.1267688873            -0.138943382
# adjclosebond_return                 -0.0773386315            -0.014176977
# adjclosestocklag1_return             0.1614923245            -0.190880712
# adjclosebondlag1_return             -0.1779989494             0.085906962
# adjclosestocklag2_return             0.2253557644             0.160241456
# adjclosebondlag2_return             -0.0085039871            -0.248644849
# adjclosestocklag3_return            -0.0666711551             0.013061645
# adjclosebondlag3_return              0.0640764188             0.055446900
# adjclosestocklag4_return            -0.2650869920             0.008604186
# adjclosebondlag4_return              0.0135208564             0.049668855
# adjclosestocklag5_return             1.0000000000            -0.411695631
# adjclosebondlag5_return             -0.4116956314             1.000000000
# adjclosestocklag6_return            -0.2601215985             0.006545833
# adjclosebondlag6_return              0.0067625724             0.043829942
#                          adjclosestocklag6_return adjclosebondlag6_return
# volume                               -0.275461763             0.028855070
# volumelag1                            0.066787121             0.180539273
# volumelag2                            0.058003769            -0.164449040
# volumelag3                           -0.017336168             0.219119997
# volumelag4                           -0.055175032             0.153432574
# volumelag5                           -0.103442135             0.478970105
# volumelag6                            0.030183451             0.157247153
# grade9price_return                   -0.299943645            -0.115489047
# grade10price_return                   0.122193831             0.018449414
# adjclosestock_return                 -0.178506319             0.207774556
# adjclosebond_return                   0.038973848            -0.110490688
# adjclosestocklag1_return              0.110578660            -0.150466443
# adjclosebondlag1_return              -0.052350641             0.011347324
# adjclosestocklag2_return              0.139586786            -0.205839814
# adjclosebondlag2_return              -0.183003512             0.070295488
# adjclosestocklag3_return              0.240605112             0.186966030
# adjclosebondlag3_return               0.029606183            -0.187046658
# adjclosestocklag4_return             -0.048137403             0.030844998
# adjclosebondlag4_return               0.018396846            -0.001892280
# adjclosestocklag5_return             -0.260121599             0.006762572
# adjclosebondlag5_return               0.006545833             0.043829942
# adjclosestocklag6_return              1.000000000            -0.388067253
# adjclosebondlag6_return              -0.388067253             1.000000000
# plot without title

# %% [markdown]
# ## VAR model - try later - if enough time...

# %%
#install.packages('vars', type = 'binary')
library(vars)

# Assuming 'data_var_subset' is a dataframe with the relevant variables for VAR model
data_var_subset <- df[c("grade10price", "adjclosestock")]

# Determine optimal number of lags
var1.select <- VARselect(data_var_subset, lag.max=6, type="const")
var1.select$selection

# Once you have the optimal number of lags, you can fit the VAR model
#optimal_lags <- var1.select$selection["AIC"]  # Choosing based on AIC, for example
#var_model <- VAR(data_var_subset, p=optimal_lags, type="const")

# Now, 'var_model' contains your fitted VAR model with the optimal lag length
# Out:
# Warning message:
# "package 'vars' was built under R version 3.6.3"Loading required package: MASS
# Loading required package: strucchange
# Warning message:
# "package 'strucchange' was built under R version 3.6.3"Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Loading required package: urca
# Warning message:
# "package 'urca' was built under R version 3.6.3"Loading required package: lmtest
# Warning message:
# "package 'lmtest' was built under R version 3.6.3"
# AIC(n)  HQ(n)  SC(n) FPE(n)
#      6      2      2      2

# %% [markdown]
# ## Visualisation

# %%
#create a long format data frame suitable for faceting with returns
long_df <- reshape2::melt(df, id.vars = "date", measure.vars = grade_returns)

#histograms for card grade returns
p1 <- ggplot(long_df, aes(x = value)) +
  geom_histogram(bins = 30, fill = "blue", alpha = 0.5) +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Returns", y = "Frequency", title = "Histograms of Card Grade Returns - Blastoise 1999")

print(p1)
# Out:
# plot without title

# %%
#histogram of stock returns
p2 <- ggplot(df, aes(x = adjclosestock_return)) +
  geom_histogram(bins = 30, fill = "red", alpha = 0.5) +
  labs(title = "Histogram of Stock Returns (Blastoise 1999)")

print(p2)
# Out:
# plot without title

# %%
#a long format data frame suitable for scatterplots with returns
long_df <- reshape2::melt(df, id.vars = c("date", "adjclosestocklag1_return"), measure.vars = grade_returns) #ADJUST FOR DIFFERENT LAGS

#scatterplots between stock returns and card grades returns
p3 <- ggplot(long_df, aes(x = adjclosestocklag1_return, y = value)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "red") +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Stock Returns", y = "Card Grade Returns", title = "Scatterplots of Stock Returns vs Card Grade Returns - Blastoise 1999")

print(p3)
# Out:
# plot without title

# %% [markdown]
# ## Choose the variables using AIC

# %%
# Load necessary library
library(stats)

# Preparing the initial full model with the dependent variable (choosing one of the grade prices as an example)
# and all potential independent variables (using returns and lagged returns)
# Note: Adjust 'grade5price' to the specific grade price return you are analyzing
full_model <- lm(grade10price_return ~ adjclosestock_return + adjclosebond_return +
                 adjclosestocklag1_return + adjclosebondlag1_return +
                 adjclosestocklag2_return + adjclosebondlag2_return +
                 adjclosestocklag3_return + adjclosebondlag3_return +
                 adjclosestocklag4_return + adjclosebondlag4_return +
                 adjclosestocklag5_return + adjclosebondlag5_return +
                 adjclosestocklag6_return + adjclosebondlag6_return +
                 volume + volumelag1 + volumelag2 + volumelag3 + 
                 volumelag4 + volumelag5 + volumelag6, data = df)

# Perform backward elimination based on AIC
reduced_model <- step(full_model, direction = "backward")

# Display the summary of the reduced model to see the selected variables and their coefficients
summary(reduced_model)
# Out:
# Start:  AIC=-22.01
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosestocklag4_return + adjclosebondlag4_return + adjclosestocklag5_return +
#     adjclosebondlag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume + volumelag1 + volumelag2 + volumelag3 + volumelag4 +
#     volumelag5 + volumelag6
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag6                1   0.00344 5.7574 -23.989
# - adjclosebondlag3_return   1   0.01001 5.7640 -23.948
# - volumelag2                1   0.01789 5.7719 -23.899
# - volumelag1                1   0.03044 5.7844 -23.821
# - volumelag3                1   0.03746 5.7914 -23.777
# - adjclosestocklag1_return  1   0.04477 5.7987 -23.732
# - adjclosestock_return      1   0.06755 5.8215 -23.590
# - adjclosestocklag5_return  1   0.11337 5.8673 -23.308
# - adjclosebondlag5_return   1   0.11734 5.8713 -23.284
# - adjclosestocklag3_return  1   0.20272 5.9567 -22.764
# - adjclosestocklag4_return  1   0.23730 5.9913 -22.556
# - adjclosebondlag4_return   1   0.26822 6.0222 -22.370
# - adjclosebondlag6_return   1   0.31304 6.0670 -22.104
# <none>                                  5.7540 -22.011
# - volumelag5                1   0.38326 6.1372 -21.689
# - adjclosestocklag2_return  1   0.47058 6.2246 -21.181
# - adjclosestocklag6_return  1   0.49040 6.2444 -21.066
# - volume                    1   0.49186 6.2458 -21.058
# - volumelag4                1   0.99127 6.7452 -18.288
# - adjclosebondlag1_return   1   1.07140 6.8254 -17.863
# - adjclosebondlag2_return   1   1.39083 7.1448 -16.217
# - adjclosebond_return       1   1.65556 7.4095 -14.907
#
# Step:  AIC=-23.99
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosestocklag4_return + adjclosebondlag4_return + adjclosestocklag5_return +
#     adjclosebondlag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume + volumelag1 + volumelag2 + volumelag3 + volumelag4 +
#     volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag3_return   1   0.01045 5.7679 -25.924
# - volumelag2                1   0.02389 5.7813 -25.840
# - volumelag3                1   0.03820 5.7956 -25.751
# - volumelag1                1   0.03908 5.7965 -25.746
# - adjclosestocklag1_return  1   0.05040 5.8078 -25.675
# - adjclosestock_return      1   0.06461 5.8220 -25.587
# - adjclosestocklag5_return  1   0.11022 5.8676 -25.306
# - adjclosebondlag5_return   1   0.11825 5.8757 -25.257
# - adjclosestocklag3_return  1   0.21999 5.9774 -24.639
# - adjclosestocklag4_return  1   0.23986 5.9973 -24.520
# - adjclosebondlag4_return   1   0.26558 6.0230 -24.366
# - adjclosebondlag6_return   1   0.32083 6.0782 -24.037
# <none>                                  5.7574 -23.989
# - volumelag5                1   0.38268 6.1401 -23.672
# - adjclosestocklag2_return  1   0.46827 6.2257 -23.174
# - volume                    1   0.49706 6.2545 -23.008
# - adjclosestocklag6_return  1   0.53152 6.2889 -22.810
# - volumelag4                1   1.06612 6.8235 -19.873
# - adjclosebondlag1_return   1   1.09505 6.8525 -19.721
# - adjclosebondlag2_return   1   1.42646 7.1839 -18.020
# - adjclosebond_return       1   1.71078 7.4682 -16.623
#
# Step:  AIC=-25.92
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag1 + volumelag2 + volumelag3 + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag3                1   0.03048 5.7983 -27.734
# - volumelag2                1   0.03137 5.7992 -27.729
# - volumelag1                1   0.04318 5.8110 -27.655
# - adjclosestocklag1_return  1   0.05731 5.8252 -27.568
# - adjclosestock_return      1   0.06688 5.8347 -27.509
# - adjclosestocklag5_return  1   0.10721 5.8751 -27.261
# - adjclosebondlag5_return   1   0.10981 5.8777 -27.245
# - adjclosestocklag4_return  1   0.24344 6.0113 -26.436
# - adjclosebondlag4_return   1   0.25577 6.0236 -26.362
# - adjclosestocklag3_return  1   0.25633 6.0242 -26.358
# - adjclosebondlag6_return   1   0.32040 6.0883 -25.978
# <none>                                  5.7679 -25.924
# - volumelag5                1   0.38935 6.1572 -25.572
# - adjclosestocklag2_return  1   0.45793 6.2258 -25.174
# - adjclosestocklag6_return  1   0.53503 6.3029 -24.730
# - volume                    1   0.53902 6.3069 -24.708
# - volumelag4                1   1.07259 6.8405 -21.784
# - adjclosebondlag1_return   1   1.08615 6.8540 -21.713
# - adjclosebondlag2_return   1   1.41612 7.1840 -20.020
# - adjclosebond_return       1   1.73923 7.5071 -18.436
#
# Step:  AIC=-27.73
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag1 + volumelag2 + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag1                1   0.04239 5.8407 -29.472
# - volumelag2                1   0.04377 5.8421 -29.463
# - adjclosestocklag1_return  1   0.06886 5.8672 -29.309
# - adjclosestock_return      1   0.08763 5.8860 -29.194
# - adjclosebondlag5_return   1   0.10232 5.9007 -29.104
# - adjclosestocklag5_return  1   0.11894 5.9173 -29.003
# - adjclosestocklag4_return  1   0.22215 6.0205 -28.381
# - adjclosebondlag4_return   1   0.23368 6.0320 -28.312
# - adjclosestocklag3_return  1   0.23647 6.0348 -28.295
# - adjclosebondlag6_return   1   0.29013 6.0885 -27.976
# <none>                                  5.7983 -27.734
# - volumelag5                1   0.38307 6.1814 -27.431
# - adjclosestocklag2_return  1   0.48236 6.2807 -26.857
# - adjclosestocklag6_return  1   0.50560 6.3039 -26.724
# - volume                    1   0.54960 6.3479 -26.474
# - volumelag4                1   1.04245 6.8408 -23.782
# - adjclosebondlag1_return   1   1.05825 6.8566 -23.699
# - adjclosebondlag2_return   1   1.49654 7.2949 -21.468
# - adjclosebond_return       1   1.76310 7.5614 -20.177
#
# Step:  AIC=-29.47
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag2 + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag2                1   0.02668 5.8674 -31.308
# - adjclosestocklag1_return  1   0.05676 5.8975 -31.124
# - adjclosebondlag5_return   1   0.10849 5.9492 -30.809
# - adjclosestock_return      1   0.12014 5.9609 -30.739
# - adjclosestocklag5_return  1   0.17510 6.0158 -30.409
# - adjclosestocklag4_return  1   0.22942 6.0701 -30.085
# <none>                                  5.8407 -29.472
# - adjclosebondlag4_return   1   0.34052 6.1813 -29.432
# - adjclosestocklag3_return  1   0.39104 6.2318 -29.139
# - volumelag5                1   0.46073 6.3015 -28.738
# - adjclosebondlag6_return   1   0.46111 6.3018 -28.736
# - adjclosestocklag2_return  1   0.57447 6.4152 -28.095
# - volume                    1   0.58197 6.4227 -28.052
# - adjclosestocklag6_return  1   0.88322 6.7240 -26.402
# - volumelag4                1   1.00056 6.8413 -25.779
# - adjclosebondlag1_return   1   1.31174 7.1525 -24.178
# - adjclosebondlag2_return   1   1.50557 7.3463 -23.216
# - adjclosebond_return       1   1.72120 7.5619 -22.174
#
# Step:  AIC=-31.31
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag1_return  1   0.06781 5.9352 -32.894
# - adjclosebondlag5_return   1   0.15948 6.0269 -32.342
# - adjclosestock_return      1   0.17084 6.0382 -32.275
# - adjclosestocklag5_return  1   0.20070 6.0681 -32.097
# - adjclosestocklag4_return  1   0.23881 6.1062 -31.872
# <none>                                  5.8674 -31.308
# - adjclosebondlag4_return   1   0.36977 6.2372 -31.108
# - adjclosebondlag6_return   1   0.43478 6.3022 -30.734
# - volumelag5                1   0.43781 6.3052 -30.717
# - adjclosestocklag3_return  1   0.50440 6.3718 -30.339
# - adjclosestocklag2_return  1   0.57056 6.4380 -29.967
# - volume                    1   0.62788 6.4953 -29.648
# - volumelag4                1   1.00232 6.8697 -27.630
# - adjclosestocklag6_return  1   1.03441 6.9018 -27.462
# - adjclosebondlag1_return   1   1.28586 7.1533 -26.174
# - adjclosebondlag2_return   1   1.64853 7.5159 -24.394
# - adjclosebond_return       1   1.75884 7.6263 -23.869
#
# Step:  AIC=-32.89
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosestocklag4_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag5_return   1   0.13782 6.0730 -34.068
# - adjclosestocklag5_return  1   0.14756 6.0828 -34.010
# - adjclosestock_return      1   0.20296 6.1382 -33.684
# - adjclosebondlag4_return   1   0.31686 6.2521 -33.022
# <none>                                  5.9352 -32.894
# - adjclosestocklag4_return  1   0.43671 6.3719 -32.338
# - adjclosestocklag3_return  1   0.50099 6.4362 -31.977
# - volumelag5                1   0.50166 6.4369 -31.973
# - adjclosestocklag2_return  1   0.50765 6.4429 -31.940
# - adjclosebondlag6_return   1   0.51641 6.4516 -31.891
# - volume                    1   0.64393 6.5792 -31.186
# - volumelag4                1   0.93494 6.8702 -29.628
# - adjclosestocklag6_return  1   0.97403 6.9093 -29.424
# - adjclosebondlag2_return   1   1.84574 7.7810 -25.146
# - adjclosebond_return       1   1.89104 7.8263 -24.937
# - adjclosebondlag1_return   1   2.08112 8.0163 -24.073
#
# Step:  AIC=-34.07
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosestocklag4_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag5_return  1   0.04989 6.1229 -35.773
# - adjclosestock_return      1   0.09875 6.1718 -35.487
# - adjclosebondlag4_return   1   0.28496 6.3580 -34.417
# <none>                                  6.0730 -34.068
# - volumelag5                1   0.37079 6.4438 -33.934
# - adjclosestocklag2_return  1   0.38152 6.4546 -33.874
# - adjclosestocklag3_return  1   0.38739 6.4604 -33.842
# - adjclosebondlag6_return   1   0.41748 6.4905 -33.674
# - adjclosestocklag4_return  1   0.44853 6.5216 -33.503
# - adjclosestocklag6_return  1   0.83993 6.9130 -31.404
# - volumelag4                1   0.87403 6.9471 -31.227
# - volume                    1   1.01333 7.0864 -30.512
# - adjclosebondlag1_return   1   2.03435 8.1074 -25.667
# - adjclosebond_return       1   2.12532 8.1984 -25.265
# - adjclosebondlag2_return   1   2.20308 8.2761 -24.925
#
# Step:  AIC=-35.77
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosestocklag4_return + adjclosebondlag4_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestock_return      1   0.12607 6.2490 -37.040
# - adjclosebondlag4_return   1   0.25695 6.3799 -36.293
# - adjclosestocklag2_return  1   0.33195 6.4549 -35.873
# <none>                                  6.1229 -35.773
# - volumelag5                1   0.35021 6.4731 -35.771
# - adjclosestocklag3_return  1   0.37902 6.5020 -35.611
# - adjclosebondlag6_return   1   0.39730 6.5202 -35.510
# - adjclosestocklag4_return  1   0.62164 6.7446 -34.292
# - adjclosestocklag6_return  1   0.79067 6.9136 -33.401
# - volumelag4                1   1.02689 7.1498 -32.192
# - volume                    1   1.06209 7.1850 -32.015
# - adjclosebondlag1_return   1   2.03103 8.1540 -27.461
# - adjclosebond_return       1   2.12026 8.2432 -27.069
# - adjclosebondlag2_return   1   2.16666 8.2896 -26.867
#
# Step:  AIC=-37.04
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosestocklag2_return + adjclosebondlag2_return + adjclosestocklag3_return +
#     adjclosestocklag4_return + adjclosebondlag4_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag4_return   1    0.2273 6.4763 -37.753
# - adjclosestocklag3_return  1    0.2797 6.5287 -37.463
# - adjclosestocklag2_return  1    0.2844 6.5334 -37.437
# - volumelag5                1    0.2968 6.5458 -37.369
# <none>                                  6.2490 -37.040
# - adjclosebondlag6_return   1    0.3701 6.6191 -36.968
# - adjclosestocklag4_return  1    0.5638 6.8128 -35.930
# - adjclosestocklag6_return  1    0.6837 6.9327 -35.301
# - volumelag4                1    0.9355 7.1845 -34.018
# - volume                    1    1.0859 7.3349 -33.272
# - adjclosebondlag2_return   1    2.1878 8.4368 -28.233
# - adjclosebondlag1_return   1    2.2748 8.5238 -27.864
# - adjclosebond_return       1    3.3524 9.6014 -23.578
#
# Step:  AIC=-37.75
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosestocklag2_return + adjclosebondlag2_return + adjclosestocklag3_return +
#     adjclosestocklag4_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume + volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag2_return  1   0.25546 6.7318 -38.361
# - volumelag5                1   0.26795 6.7442 -38.294
# - adjclosestocklag3_return  1   0.30197 6.7783 -38.113
# - adjclosebondlag6_return   1   0.36104 6.8373 -37.800
# <none>                                  6.4763 -37.753
# - adjclosestocklag6_return  1   0.68704 7.1633 -36.124
# - volumelag4                1   0.77925 7.2555 -35.663
# - volume                    1   1.01899 7.4953 -34.493
# - adjclosestocklag4_return  1   1.05489 7.5312 -34.321
# - adjclosebondlag2_return   1   2.00508 8.4814 -30.043
# - adjclosebondlag1_return   1   2.04889 8.5252 -29.858
# - adjclosebond_return       1   3.15765 9.6339 -25.456
#
# Step:  AIC=-38.36
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag4 + volumelag5
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag5                1   0.12780 6.8596 -39.684
# - adjclosestocklag3_return  1   0.14064 6.8724 -39.616
# - adjclosebondlag6_return   1   0.29664 7.0284 -38.808
# <none>                                  6.7318 -38.361
# - adjclosestocklag6_return  1   0.56502 7.2968 -37.459
# - volumelag4                1   0.80098 7.5327 -36.313
# - adjclosestocklag4_return  1   0.89406 7.6258 -35.871
# - volume                    1   0.98654 7.7183 -35.437
# - adjclosebondlag2_return   1   1.84892 8.5807 -31.624
# - adjclosebondlag1_return   1   1.87835 8.6101 -31.501
# - adjclosebond_return       1   2.95487 9.6866 -27.260
#
# Step:  AIC=-39.68
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosestocklag4_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume +
#     volumelag4
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag3_return  1   0.13378 6.9933 -40.988
# - adjclosebondlag6_return   1   0.18048 7.0400 -40.749
# <none>                                  6.8596 -39.684
# - adjclosestocklag6_return  1   0.49860 7.3582 -39.158
# - volumelag4                1   0.72794 7.5875 -38.053
# - adjclosestocklag4_return  1   0.87174 7.7313 -37.377
# - volume                    1   0.89917 7.7587 -37.249
# - adjclosebondlag2_return   1   1.84535 8.7049 -33.107
# - adjclosebondlag1_return   1   1.90068 8.7602 -32.879
# - adjclosebond_return       1   2.90887 9.7684 -28.957
#
# Step:  AIC=-40.99
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag4_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume + volumelag4
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag6_return   1   0.10331 7.0966 -42.460
# - adjclosestocklag6_return  1   0.38141 7.3747 -41.076
# <none>                                  6.9933 -40.988
# - volumelag4                1   0.68111 7.6745 -39.642
# - adjclosestocklag4_return  1   0.74904 7.7424 -39.325
# - volume                    1   0.88896 7.8823 -38.680
# - adjclosebondlag1_return   1   1.81328 8.8066 -34.689
# - adjclosebondlag2_return   1   1.87363 8.8670 -34.443
# - adjclosebond_return       1   2.83922 9.8326 -30.722
#
# Step:  AIC=-42.46
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag4_return + adjclosestocklag6_return +
#     volume + volumelag4
#
#                            Df Sum of Sq     RSS     AIC
# - adjclosestocklag6_return  1   0.28660  7.3832 -43.035
# <none>                                   7.0966 -42.460
# - volumelag4                1   0.62659  7.7232 -41.414
# - adjclosestocklag4_return  1   0.74639  7.8430 -40.860
# - volume                    1   0.85114  7.9478 -40.383
# - adjclosebondlag1_return   1   1.84447  8.9411 -36.143
# - adjclosebondlag2_return   1   1.88171  8.9784 -35.993
# - adjclosebond_return       1   2.92857 10.0252 -32.023
#
# Step:  AIC=-43.03
# grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag4_return + volume +
#     volumelag4
#
#                            Df Sum of Sq     RSS     AIC
# <none>                                   7.3832 -43.035
# - volume                    1   0.64598  8.0292 -42.015
# - volumelag4                1   0.67561  8.0589 -41.883
# - adjclosestocklag4_return  1   0.76262  8.1459 -41.496
# - adjclosebondlag1_return   1   1.99360  9.3768 -36.430
# - adjclosebondlag2_return   1   2.17140  9.5547 -35.754
# - adjclosebond_return       1   2.81655 10.1998 -33.401
# Call:
# lm(formula = grade10price_return ~ adjclosebond_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag4_return + volume +
#     volumelag4, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.26812 -0.22153  0.06991  0.27494  0.76058
#
# Coefficients:
#                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)               4.529e-02  1.006e+00   0.045  0.96440
# adjclosebond_return      -3.874e+00  1.165e+00  -3.326  0.00240 **
# adjclosebondlag1_return   3.402e+00  1.216e+00   2.798  0.00904 **
# adjclosebondlag2_return  -3.252e+00  1.114e+00  -2.920  0.00670 **
# adjclosestocklag4_return -2.878e+00  1.663e+00  -1.731  0.09413 .
# volume                    1.219e-11  7.650e-12   1.593  0.12203
# volumelag4               -1.214e-11  7.454e-12  -1.629  0.11413
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5046 on 29 degrees of freedom
# Multiple R-squared:  0.4978,	Adjusted R-squared:  0.3939
# F-statistic: 4.791 on 6 and 29 DF,  p-value: 0.001659

# %% [markdown]
# ## Models

# %% [markdown]
# ### OLS

# %%
#OLS
ols_model <- lm(grade10price_return ~ adjclosestocklag1_return + 
    adjclosebondlag3_return + log(volumelag3)  , data = df) 

print(summary(ols_model))

library(car)

# Calculate VIF
vif_result <- vif(ols_model)
print(vif_result)

library(lmtest)

# Perform the Breusch-Pagan test
bp_test <- bptest(ols_model)

# Print the test results
print(bp_test)
# Out:
# Call:
# lm(formula = grade10price_return ~ adjclosestocklag1_return +
#     adjclosebondlag3_return + log(volumelag3), data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.74879 -0.11544  0.00362  0.10559  0.89234
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               -7.2267     4.1598  -1.737  0.08645 .
# adjclosestocklag1_return  -1.0015     0.6166  -1.624  0.10850
# adjclosebondlag3_return   -1.1364     0.3355  -3.387  0.00113 **
# log(volumelag3)            0.2891     0.1654   1.747  0.08466 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2606 on 75 degrees of freedom
# Multiple R-squared:  0.1754,	Adjusted R-squared:  0.1424
# F-statistic: 5.317 on 3 and 75 DF,  p-value: 0.002238
#
# adjclosestocklag1_return  adjclosebondlag3_return          log(volumelag3)
#                 1.016533                 1.001760                 1.017718
#
# 	studentized Breusch-Pagan test
#
# data:  ols_model
# BP = 6.5551, df = 3, p-value = 0.08751

# %% [markdown]
# ### Quantile regression

# %%
#Quantile regression
library(quantreg)

quantile_model <- rq(grade10price_return ~ adjclosestocklag1_return + adjclosebondlag3_return + log(volumelag3) , data = df, tau = seq(from=0.05, to=0.95, by=0.05))  #change tau for different quantiles
                                                                                                                                   

#print summary of quantile regression models
for(grade_return in grade_returns) {
  #print(paste("Summary of quantile regression model for:", grade_return))
  #print(summary(quantile_models[[grade_return]]))
}

#uncomment the last two commented rows (in the previous loop) if you want to see the results for quantiles from 0.05 to 0.95, by 0.05 step

# %% [markdown]
# #### Results for different quantiles of the grade 10 prices x OLS estimates (red line)

# %%
plot(summary(quantile_model))
# Out:
# Plot with title "log(volumelag3)"
