# %% [markdown]
# # Analysis part - Full_Art_M_Charizard_EX___Holo_2016_Evolutions

# %%
library(ggplot2)
library(quantreg)


df = read.csv('lagged_merged_datasets_final/merged_Full_Art_M_Charizard_EX___Holo_2016_Evolutions.csv')

#convert prices to returns
grades <- grep("grade[0-9]+price", names(df), value = TRUE)
grade_returns <- sapply(grades, function(x) paste0(x, "_return"))

for(grade in grades) {
  df[paste(grade, "return", sep = "_")] <- c(NA, diff(log(df[[grade]])))
}

#convert adjclosestock and adjclosebond (including their lags) to returns
stock_bond_cols <- grep("adjclose(stock|bond)(lag[0-9]+)?", names(df), value = TRUE)

for(col in stock_bond_cols) {
  df[paste0(col, "_return")] <- c(NA, diff(log(df[[col]])))
}


#convert volume and its lags to 'returns'
volume_cols <- grep("volume(lag[0-9]+)?", names(df), value = TRUE)

for(col in volume_cols) {
  df[paste0(col, "_return")] <- c(NA, diff(log(df[[col]])))  # Adding 1 to avoid log(0) issues
}

#remove rows with NA in the newly created return columns
df <- na.omit(df)

print(head(df))
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Warning message:
# "package 'quantreg' was built under R version 3.6.3"Loading required package: SparseM
# Warning message:
# "package 'SparseM' was built under R version 3.6.3"
# Attaching package: 'SparseM'
#
# The following object is masked from 'package:base':
#
#     backsolve
#         date grade8price grade9price grade10price adjclosestock      volume
# 2 2017-01-01       12.38    52.06750    131.27778       2278.87 70576420000
# 3 2017-02-01       12.38    53.60375    136.40833       2363.64 69260940000
# 4 2017-03-01       12.38    39.03750    107.87583       2362.72 81664010000
# 5 2017-04-01       12.38    32.21200     83.70467       2384.20 65369860000
# 6 2017-05-01       12.38    31.99800     66.20167       2411.80 79719460000
# 7 2017-06-01       12.38    31.38444     64.65214       2423.41 81078810000
#   adjclosebond  stockreturns bondadjusted excessreturns adjclosestocklag1
# 2        3.051  0.0178843582      0.03051    0.02180204           2238.83
# 3        2.968  0.0371981601      0.02968    0.06440241           2278.87
# 4        3.018 -0.0003891971      0.03018   -0.01723554           2363.64
# 5        2.952  0.0090912087      0.02952    0.03095999           2362.72
# 6        2.857  0.0115762512      0.02857    0.04375775           2384.20
# 7        2.840  0.0048137752      0.02840    0.01076414           2411.80
#   adjclosebondlag1  volumelag1 adjclosestocklag2 adjclosebondlag2  volumelag2
# 2            3.063 75344550000           2198.81            3.017 88445380000
# 3            3.051 70576420000           2238.83            3.063 75344550000
# 4            2.968 69260940000           2278.87            3.051 70576420000
# 5            3.018 81664010000           2363.64            2.968 69260940000
# 6            2.952 65369860000           2362.72            3.018 81664010000
# 7            2.857 79719460000           2384.20            2.952 65369860000
#   adjclosestocklag3 adjclosebondlag3  volumelag3 adjclosestocklag4
# 2           2126.15            2.589 72915530000           2168.27
# 3           2198.81            3.017 88445380000           2126.15
# 4           2238.83            3.063 75344550000           2198.81
# 5           2278.87            3.051 70576420000           2238.83
# 6           2363.64            2.968 69260940000           2278.87
# 7           2362.72            3.018 81664010000           2363.64
#   adjclosebondlag4  volumelag4 adjclosestocklag5 adjclosebondlag5  volumelag5
# 2            2.336 77023620000           2170.95            2.231 75610310000
# 3            2.589 72915530000           2168.27            2.336 77023620000
# 4            3.017 88445380000           2126.15            2.589 72915530000
# 5            3.063 75344550000           2198.81            3.017 88445380000
# 6            3.051 70576420000           2238.83            3.063 75344550000
# 7            2.968 69260940000           2278.87            3.051 70576420000
#   adjclosestocklag6 adjclosebondlag6  volumelag6 grade8price_return
# 2           2173.60            2.182 69530250000                  0
# 3           2170.95            2.231 75610310000                  0
# 4           2168.27            2.336 77023620000                  0
# 5           2126.15            2.589 72915530000                  0
# 6           2198.81            3.017 88445380000                  0
# 7           2238.83            3.063 75344550000                  0
#   grade9price_return grade10price_return adjclosestock_return
# 2       -0.418487927         -0.27191002         0.0177263146
# 3        0.029078075          0.03833732         0.0365230007
# 4       -0.317096306         -0.23467196        -0.0003892729
# 5       -0.192183669         -0.25368614         0.0090501325
# 6       -0.006665653         -0.23458909         0.0115097591
# 7       -0.019361031         -0.02368439         0.0048022260
#   adjclosebond_return adjclosestocklag1_return adjclosebondlag1_return
# 2        -0.003925372             0.0180371113             0.015131869
# 3        -0.027581141             0.0177263146            -0.003925372
# 4         0.016706020             0.0365230007            -0.027581141
# 5        -0.022111449            -0.0003892729             0.016706020
# 6        -0.032710711             0.0090501325            -0.022111449
# 7        -0.005968141             0.0115097591            -0.032710711
#   adjclosestocklag2_return adjclosebondlag2_return adjclosestocklag3_return
# 2             0.0336035450             0.152991251            -0.0196168370
# 3             0.0180371113             0.015131869             0.0336035450
# 4             0.0177263146            -0.003925372             0.0180371113
# 5             0.0365230007            -0.027581141             0.0177263146
# 6            -0.0003892729             0.016706020             0.0365230007
# 7             0.0090501325            -0.022111449            -0.0003892729
#   adjclosebondlag3_return adjclosestocklag4_return adjclosebondlag4_return
# 2             0.102831645             -0.001235214             0.045990159
# 3             0.152991251             -0.019616837             0.102831645
# 4             0.015131869              0.033603545             0.152991251
# 5            -0.003925372              0.018037111             0.015131869
# 6            -0.027581141              0.017726315            -0.003925372
# 7             0.016706020              0.036523001            -0.027581141
#   adjclosestocklag5_return adjclosebondlag5_return adjclosestocklag6_return
# 2             -0.001219987             0.022208040              0.034990433
# 3             -0.001235214             0.045990159             -0.001219987
# 4             -0.019616837             0.102831645             -0.001235214
# 5              0.033603545             0.152991251             -0.019616837
# 6              0.018037111             0.015131869              0.033603545
# 7              0.017726315            -0.003925372              0.018037111
#   adjclosebondlag6_return volume_return volumelag1_return volumelag2_return
# 2             -0.05570609   -0.06537550       -0.16031359        0.19308354
# 3              0.02220804   -0.01881498       -0.06537550       -0.16031359
# 4              0.04599016    0.16473228       -0.01881498       -0.06537550
# 5              0.10283165   -0.22255209        0.16473228       -0.01881498
# 6              0.15299125    0.19845243       -0.22255209        0.16473228
# 7              0.01513187    0.01690792        0.19845243       -0.22255209
#   volumelag3_return volumelag4_return volumelag5_return volumelag6_return
# 2       -0.05481048        0.01851948        0.08383074       -0.22245167
# 3        0.19308354       -0.05481048        0.01851948        0.08383074
# 4       -0.16031359        0.19308354       -0.05481048        0.01851948
# 5       -0.06537550       -0.16031359        0.19308354       -0.05481048
# 6       -0.01881498       -0.06537550       -0.16031359        0.19308354
# 7        0.16473228       -0.01881498       -0.06537550       -0.16031359

# %%
createReturnsCorrelationMatrix <- function(df) {
  # Load necessary libraries
  library(ggplot2)
  library(reshape2)
  
  # Use a simplified pattern to include both "_return" columns and any "volume" columns
  pattern <- "_return"
  selected_columns <- grep(pattern, names(df), value = TRUE)
  
  # Calculate the correlation matrix for the selected columns
  correlation_matrix <- cor(df[, selected_columns], use = "complete.obs")
  
  # Print the correlation matrix to the console
  print(correlation_matrix)
  
  # Melt the correlation matrix for visualization
  melted_correlation_matrix <- melt(correlation_matrix)
  
  # Create the ggplot object for the correlation matrix
  plot <- ggplot(data = melted_correlation_matrix, aes(x=Var1, y=Var2, fill=value)) +
    geom_tile() +
    scale_fill_gradient2(midpoint=0, low="blue", high="red", mid="white") +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    labs(x='', y='', title='Correlation Matrix of Returns', fill='Correlation')
  
  # Explicitly print the ggplot object to ensure it's displayed
  print(plot)
  
  # Return the correlation matrix as well
  return(correlation_matrix)
}

# Assuming your adjusted dataset is in 'df'
# Example usage:
correlation_matrix <- createReturnsCorrelationMatrix(df)
# Out:
#                          grade8price_return grade9price_return
# grade8price_return              1.000000000        -0.02948929
# grade9price_return             -0.029489289         1.00000000
# grade10price_return             0.162132095         0.12371614
# adjclosestock_return            0.083623977         0.03314405
# adjclosebond_return             0.127496606        -0.03850347
# adjclosestocklag1_return        0.162494634        -0.19956468
# adjclosebondlag1_return         0.067069149         0.08576510
# adjclosestocklag2_return       -0.181541863         0.29073123
# adjclosebondlag2_return        -0.048536286        -0.12665229
# adjclosestocklag3_return       -0.147504793        -0.20753094
# adjclosebondlag3_return        -0.217644776        -0.18354672
# adjclosestocklag4_return        0.036610090         0.09519539
# adjclosebondlag4_return        -0.014924040        -0.01042496
# adjclosestocklag5_return       -0.010907038        -0.04722913
# adjclosebondlag5_return        -0.136457857        -0.04981661
# adjclosestocklag6_return       -0.022955430         0.04794813
# adjclosebondlag6_return         0.099582067        -0.06349915
# volume_return                  -0.007201491         0.16047990
# volumelag1_return              -0.111262538         0.04856039
# volumelag2_return               0.155222637        -0.12270004
# volumelag3_return               0.152367320         0.09495978
# volumelag4_return              -0.093376304        -0.06095666
# volumelag5_return               0.089542016         0.10450788
# volumelag6_return               0.033826089        -0.17090898
#                          grade10price_return adjclosestock_return
# grade8price_return                0.16213210           0.08362398
# grade9price_return                0.12371614           0.03314405
# grade10price_return               1.00000000           0.09072086
# adjclosestock_return              0.09072086           1.00000000
# adjclosebond_return               0.03264592           0.01634749
# adjclosestocklag1_return         -0.26156600          -0.18804546
# adjclosebondlag1_return          -0.12716552          -0.02717815
# adjclosestocklag2_return          0.20753984          -0.08087134
# adjclosebondlag2_return           0.12440128          -0.01997155
# adjclosestocklag3_return         -0.03694473           0.05398355
# adjclosebondlag3_return          -0.29617809          -0.04747921
# adjclosestocklag4_return         -0.08801100          -0.01768267
# adjclosebondlag4_return          -0.07203937          -0.15423809
# adjclosestocklag5_return          0.07548677          -0.01058931
# adjclosebondlag5_return          -0.04744594          -0.14734656
# adjclosestocklag6_return         -0.18998987          -0.10478871
# adjclosebondlag6_return          -0.13462779           0.11934086
# volume_return                    -0.08073104          -0.34198252
# volumelag1_return                 0.25375382           0.05915452
# volumelag2_return                -0.26781023           0.11084382
# volumelag3_return                 0.16411169          -0.04945872
# volumelag4_return                -0.01800782          -0.05586801
# volumelag5_return                 0.07433095           0.23592950
# volumelag6_return                -0.01005479          -0.11329341
#                          adjclosebond_return adjclosestocklag1_return
# grade8price_return               0.127496606               0.16249463
# grade9price_return              -0.038503465              -0.19956468
# grade10price_return              0.032645919              -0.26156600
# adjclosestock_return             0.016347492              -0.18804546
# adjclosebond_return              1.000000000               0.13726126
# adjclosestocklag1_return         0.137261261               1.00000000
# adjclosebondlag1_return          0.134751246               0.01683608
# adjclosestocklag2_return        -0.079174068              -0.18757524
# adjclosebondlag2_return          0.067756419              -0.02098285
# adjclosestocklag3_return         0.022554697              -0.08125669
# adjclosebondlag3_return         -0.004080826              -0.01823680
# adjclosestocklag4_return        -0.090883934               0.05202610
# adjclosebondlag4_return         -0.016154098              -0.04482099
# adjclosestocklag5_return         0.005652009              -0.01595724
# adjclosebondlag5_return          0.129718553              -0.15448966
# adjclosestocklag6_return        -0.004276617              -0.01071720
# adjclosebondlag6_return          0.019340938              -0.14806042
# volume_return                   -0.148400541              -0.06210095
# volumelag1_return               -0.079756511              -0.35554529
# volumelag2_return                0.054071923               0.05986525
# volumelag3_return                0.016338025               0.10987583
# volumelag4_return                0.053505173              -0.04860902
# volumelag5_return               -0.082303726              -0.05360813
# volumelag6_return                0.016392091               0.22967203
#                          adjclosebondlag1_return adjclosestocklag2_return
# grade8price_return                   0.067069149             -0.181541863
# grade9price_return                   0.085765097              0.290731233
# grade10price_return                 -0.127165517              0.207539843
# adjclosestock_return                -0.027178148             -0.080871344
# adjclosebond_return                  0.134751246             -0.079174068
# adjclosestocklag1_return             0.016836084             -0.187575235
# adjclosebondlag1_return              1.000000000              0.138704564
# adjclosestocklag2_return             0.138704564              1.000000000
# adjclosebondlag2_return              0.135295612              0.033566322
# adjclosestocklag3_return            -0.080946566             -0.186692409
# adjclosebondlag3_return              0.070155014             -0.018616362
# adjclosestocklag4_return             0.023255674             -0.090805676
# adjclosebondlag4_return             -0.004096060             -0.008140183
# adjclosestocklag5_return            -0.093652354              0.061636252
# adjclosebondlag5_return             -0.015545528             -0.046263834
# adjclosestocklag6_return             0.007523619             -0.018740413
# adjclosebondlag6_return              0.128079076             -0.152012932
# volume_return                        0.123852803              0.142907331
# volumelag1_return                   -0.159547849             -0.051460870
# volumelag2_return                   -0.077306888             -0.369476915
# volumelag3_return                    0.053333080              0.057688732
# volumelag4_return                    0.016268058              0.113147394
# volumelag5_return                    0.054026723             -0.041347515
# volumelag6_return                   -0.084098830             -0.060882700
#                          adjclosebondlag2_return adjclosestocklag3_return
# grade8price_return                  -0.048536286             -0.147504793
# grade9price_return                  -0.126652289             -0.207530945
# grade10price_return                  0.124401283             -0.036944730
# adjclosestock_return                -0.019971551              0.053983552
# adjclosebond_return                  0.067756419              0.022554697
# adjclosestocklag1_return            -0.020982848             -0.081256688
# adjclosebondlag1_return              0.135295612             -0.080946566
# adjclosestocklag2_return             0.033566322             -0.186692409
# adjclosebondlag2_return              1.000000000              0.116899335
# adjclosestocklag3_return             0.116899335              1.000000000
# adjclosebondlag3_return              0.164371471              0.032135105
# adjclosestocklag4_return            -0.073677997             -0.176738821
# adjclosebondlag4_return              0.069179840             -0.031565638
# adjclosestocklag5_return             0.004462196             -0.104231731
# adjclosebondlag5_return              0.003282351             -0.006031767
# adjclosestocklag6_return            -0.070689781              0.066416451
# adjclosebondlag6_return             -0.043199399             -0.052150495
# volume_return                       -0.200826588             -0.062747886
# volumelag1_return                    0.076968760              0.130261918
# volumelag2_return                   -0.112660463             -0.041663624
# volumelag3_return                   -0.084139192             -0.367332018
# volumelag4_return                    0.051520567              0.053749401
# volumelag5_return                    0.021836230              0.104443689
# volumelag6_return                    0.019630168             -0.032516392
#                          adjclosebondlag3_return adjclosestocklag4_return
# grade8price_return                  -0.217644776               0.03661009
# grade9price_return                  -0.183546717               0.09519539
# grade10price_return                 -0.296178089              -0.08801100
# adjclosestock_return                -0.047479206              -0.01768267
# adjclosebond_return                 -0.004080826              -0.09088393
# adjclosestocklag1_return            -0.018236804               0.05202610
# adjclosebondlag1_return              0.070155014               0.02325567
# adjclosestocklag2_return            -0.018616362              -0.09080568
# adjclosebondlag2_return              0.164371471              -0.07367800
# adjclosestocklag3_return             0.032135105              -0.17673882
# adjclosebondlag3_return              1.000000000               0.10407392
# adjclosestocklag4_return             0.104073923               1.00000000
# adjclosebondlag4_return              0.180721156               0.04573824
# adjclosestocklag5_return            -0.063107107              -0.15949624
# adjclosebondlag5_return              0.067837495              -0.03733954
# adjclosestocklag6_return             0.003561698              -0.11998869
# adjclosebondlag6_return              0.004270874               0.01231568
# volume_return                        0.095186533               0.13675072
# volumelag1_return                   -0.195679855              -0.02307263
# volumelag2_return                    0.074781609               0.10090301
# volumelag3_return                   -0.116749907              -0.04058131
# volumelag4_return                   -0.078938573              -0.36569763
# volumelag5_return                    0.063801316               0.06051326
# volumelag6_return                    0.003683948               0.11050445
#                          adjclosebondlag4_return adjclosestocklag5_return
# grade8price_return                  -0.014924040             -0.010907038
# grade9price_return                  -0.010424956             -0.047229131
# grade10price_return                 -0.072039371              0.075486768
# adjclosestock_return                -0.154238091             -0.010589309
# adjclosebond_return                 -0.016154098              0.005652009
# adjclosestocklag1_return            -0.044820994             -0.015957243
# adjclosebondlag1_return             -0.004096060             -0.093652354
# adjclosestocklag2_return            -0.008140183              0.061636252
# adjclosebondlag2_return              0.069179840              0.004462196
# adjclosestocklag3_return            -0.031565638             -0.104231731
# adjclosebondlag3_return              0.180721156             -0.063107107
# adjclosestocklag4_return             0.045738241             -0.159496237
# adjclosebondlag4_return              1.000000000              0.085780731
# adjclosestocklag5_return             0.085780731              1.000000000
# adjclosebondlag5_return              0.187565217              0.052788484
# adjclosestocklag6_return            -0.048018027             -0.145965573
# adjclosebondlag6_return              0.048806894             -0.058478381
# volume_return                       -0.019957192              0.044964979
# volumelag1_return                    0.056372508              0.093161575
# volumelag2_return                   -0.165652335              0.013249707
# volumelag3_return                    0.072634550              0.102386346
# volumelag4_return                   -0.121385374             -0.047945754
# volumelag5_return                   -0.083548842             -0.382121282
# volumelag6_return                    0.052314461              0.059846987
#                          adjclosebondlag5_return adjclosestocklag6_return
# grade8price_return                  -0.136457857             -0.022955430
# grade9price_return                  -0.049816608              0.047948131
# grade10price_return                 -0.047445938             -0.189989869
# adjclosestock_return                -0.147346559             -0.104788707
# adjclosebond_return                  0.129718553             -0.004276617
# adjclosestocklag1_return            -0.154489662             -0.010717196
# adjclosebondlag1_return             -0.015545528              0.007523619
# adjclosestocklag2_return            -0.046263834             -0.018740413
# adjclosebondlag2_return              0.003282351             -0.070689781
# adjclosestocklag3_return            -0.006031767              0.066416451
# adjclosebondlag3_return              0.067837495              0.003561698
# adjclosestocklag4_return            -0.037339535             -0.119988690
# adjclosebondlag4_return              0.187565217             -0.048018027
# adjclosestocklag5_return             0.052788484             -0.145965573
# adjclosebondlag5_return              1.000000000              0.082977641
# adjclosestocklag6_return             0.082977641              1.000000000
# adjclosebondlag6_return              0.192711245              0.062272660
# volume_return                        0.088817370             -0.080070002
# volumelag1_return                   -0.009499897              0.074974028
# volumelag2_return                    0.050133930              0.078311161
# volumelag3_return                   -0.166231003              0.011129335
# volumelag4_return                    0.074600034              0.107843955
# volumelag5_return                   -0.117838731             -0.037787932
# volumelag6_return                   -0.084561123             -0.386334360
#                          adjclosebondlag6_return volume_return
# grade8price_return                   0.099582067  -0.007201491
# grade9price_return                  -0.063499147   0.160479897
# grade10price_return                 -0.134627789  -0.080731041
# adjclosestock_return                 0.119340860  -0.341982523
# adjclosebond_return                  0.019340938  -0.148400541
# adjclosestocklag1_return            -0.148060419  -0.062100949
# adjclosebondlag1_return              0.128079076   0.123852803
# adjclosestocklag2_return            -0.152012932   0.142907331
# adjclosebondlag2_return             -0.043199399  -0.200826588
# adjclosestocklag3_return            -0.052150495  -0.062747886
# adjclosebondlag3_return              0.004270874   0.095186533
# adjclosestocklag4_return             0.012315675   0.136750718
# adjclosebondlag4_return              0.048806894  -0.019957192
# adjclosestocklag5_return            -0.058478381   0.044964979
# adjclosebondlag5_return              0.192711245   0.088817370
# adjclosestocklag6_return             0.062272660  -0.080070002
# adjclosebondlag6_return              1.000000000   0.062062535
# volume_return                        0.062062535   1.000000000
# volumelag1_return                    0.058649424  -0.442539757
# volumelag2_return                    0.011563697  -0.038259113
# volumelag3_return                    0.053138707   0.167016932
# volumelag4_return                   -0.173612952  -0.186800021
# volumelag5_return                    0.061943524   0.010276407
# volumelag6_return                   -0.107295667  -0.042742081
#                          volumelag1_return volumelag2_return volumelag3_return
# grade8price_return            -0.111262538        0.15522264        0.15236732
# grade9price_return             0.048560386       -0.12270004        0.09495978
# grade10price_return            0.253753817       -0.26781023        0.16411169
# adjclosestock_return           0.059154523        0.11084382       -0.04945872
# adjclosebond_return           -0.079756511        0.05407192        0.01633803
# adjclosestocklag1_return      -0.355545288        0.05986525        0.10987583
# adjclosebondlag1_return       -0.159547849       -0.07730689        0.05333308
# adjclosestocklag2_return      -0.051460870       -0.36947692        0.05768873
# adjclosebondlag2_return        0.076968760       -0.11266046       -0.08413919
# adjclosestocklag3_return       0.130261918       -0.04166362       -0.36733202
# adjclosebondlag3_return       -0.195679855        0.07478161       -0.11674991
# adjclosestocklag4_return      -0.023072629        0.10090301       -0.04058131
# adjclosebondlag4_return        0.056372508       -0.16565233        0.07263455
# adjclosestocklag5_return       0.093161575        0.01324971        0.10238635
# adjclosebondlag5_return       -0.009499897        0.05013393       -0.16623100
# adjclosestocklag6_return       0.074974028        0.07831116        0.01112934
# adjclosebondlag6_return        0.058649424        0.01156370        0.05313871
# volume_return                 -0.442539757       -0.03825911        0.16701693
# volumelag1_return              1.000000000       -0.40812238       -0.03680183
# volumelag2_return             -0.408122378        1.00000000       -0.42037678
# volumelag3_return             -0.036801834       -0.42037678        1.00000000
# volumelag4_return              0.160539501       -0.02630454       -0.42099295
# volumelag5_return             -0.222336815        0.18661357       -0.02884577
# volumelag6_return              0.020261746       -0.23946462        0.19038732
#                          volumelag4_return volumelag5_return volumelag6_return
# grade8price_return             -0.09337630        0.08954202       0.033826089
# grade9price_return             -0.06095666        0.10450788      -0.170908980
# grade10price_return            -0.01800782        0.07433095      -0.010054788
# adjclosestock_return           -0.05586801        0.23592950      -0.113293414
# adjclosebond_return             0.05350517       -0.08230373       0.016392091
# adjclosestocklag1_return       -0.04860902       -0.05360813       0.229672029
# adjclosebondlag1_return         0.01626806        0.05402672      -0.084098830
# adjclosestocklag2_return        0.11314739       -0.04134752      -0.060882700
# adjclosebondlag2_return         0.05152057        0.02183623       0.019630168
# adjclosestocklag3_return        0.05374940        0.10444369      -0.032516392
# adjclosebondlag3_return        -0.07893857        0.06380132       0.003683948
# adjclosestocklag4_return       -0.36569763        0.06051326       0.110504446
# adjclosebondlag4_return        -0.12138537       -0.08354884       0.052314461
# adjclosestocklag5_return       -0.04794575       -0.38212128       0.059846987
# adjclosebondlag5_return         0.07460003       -0.11783873      -0.084561123
# adjclosestocklag6_return        0.10784395       -0.03778793      -0.386334360
# adjclosebondlag6_return        -0.17361295        0.06194352      -0.107295667
# volume_return                  -0.18680002        0.01027641      -0.042742081
# volumelag1_return               0.16053950       -0.22233682       0.020261746
# volumelag2_return              -0.02630454        0.18661357      -0.239464624
# volumelag3_return              -0.42099295       -0.02884577       0.190387323
# volumelag4_return               1.00000000       -0.42308419      -0.031488702
# volumelag5_return              -0.42308419        1.00000000      -0.428722124
# volumelag6_return              -0.03148870       -0.42872212       1.000000000
# plot without title

# %% [markdown]
# ## VAR model - try later - if enough time...

# %% [markdown]
# ## Visualisation

# %%
#create a long format data frame suitable for faceting with returns
long_df <- reshape2::melt(df, id.vars = "date", measure.vars = grade_returns)

#histograms for card grade returns
p1 <- ggplot(long_df, aes(x = value)) +
  geom_histogram(bins = 30, fill = "blue", alpha = 0.5) +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Returns", y = "Frequency", title = "Histograms of Card Grade Returns - Blastoise 1999")

print(p1)
# Out:
# plot without title

# %%
#histogram of stock returns
p2 <- ggplot(df, aes(x = adjclosestock_return)) +
  geom_histogram(bins = 30, fill = "red", alpha = 0.5) +
  labs(title = "Histogram of Stock Returns (Blastoise 1999)")

print(p2)
# Out:
# plot without title

# %%
#a long format data frame suitable for scatterplots with returns
long_df <- reshape2::melt(df, id.vars = c("date", "adjclosestocklag1_return"), measure.vars = grade_returns) #ADJUST FOR DIFFERENT LAGS

#scatterplots between stock returns and card grades returns
p3 <- ggplot(long_df, aes(x = adjclosestocklag1_return, y = value)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "red") +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Stock Returns", y = "Card Grade Returns", title = "Scatterplots of Stock Returns vs Card Grade Returns - Blastoise 1999")

print(p3)
# Out:
# plot without title

# %% [markdown]
# ## Choose the variables using AIC

# %%
# Load necessary library
library(stats)

# Preparing the initial full model with the dependent variable (choosing one of the grade prices as an example)
# and all potential independent variables (using returns and lagged returns)
# Note: Adjust 'grade5price' to the specific grade price return you are analyzing
full_model <- lm(grade10price_return ~ adjclosestock_return + adjclosebond_return +
                 adjclosestocklag1_return + adjclosebondlag1_return +
                 adjclosestocklag2_return + adjclosebondlag2_return +
                 adjclosestocklag3_return + adjclosebondlag3_return +
                 adjclosestocklag4_return + adjclosebondlag4_return +
                 adjclosestocklag5_return + adjclosebondlag5_return +
                 adjclosestocklag6_return + adjclosebondlag6_return +
                 volume_return + volumelag1_return + volumelag2_return + volumelag3_return + 
                 volumelag4_return + volumelag5_return + volumelag6_return, data = df)

# Perform backward elimination based on AIC
reduced_model <- step(full_model, direction = "backward")

# Display the summary of the reduced model to see the selected variables and their coefficients
summary(reduced_model)
# Out:
# Start:  AIC=-192
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosestocklag4_return + adjclosebondlag4_return + adjclosestocklag5_return +
#     adjclosebondlag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume_return + volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag4_return + volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestock_return      1  0.000000 3.4058 -194.00
# - volumelag4_return         1  0.000140 3.4060 -194.00
# - adjclosestocklag4_return  1  0.000313 3.4062 -193.99
# - volume_return             1  0.001201 3.4070 -193.97
# - adjclosebondlag5_return   1  0.001980 3.4078 -193.95
# - volumelag6_return         1  0.005068 3.4109 -193.88
# - adjclosestocklag5_return  1  0.005193 3.4110 -193.88
# - adjclosestocklag3_return  1  0.006071 3.4119 -193.86
# - volumelag1_return         1  0.015421 3.4213 -193.66
# - adjclosebondlag4_return   1  0.026683 3.4325 -193.41
# - adjclosestocklag2_return  1  0.026757 3.4326 -193.40
# - volumelag3_return         1  0.032540 3.4384 -193.28
# - volumelag2_return         1  0.034245 3.4401 -193.24
# - volumelag5_return         1  0.041853 3.4477 -193.07
# - adjclosebond_return       1  0.047408 3.4533 -192.95
# - adjclosebondlag6_return   1  0.086845 3.4927 -192.09
# - adjclosebondlag2_return   1  0.089448 3.4953 -192.03
# <none>                                  3.4058 -192.00
# - adjclosebondlag1_return   1  0.093043 3.4989 -191.95
# - adjclosestocklag6_return  1  0.109400 3.5152 -191.59
# - adjclosestocklag1_return  1  0.166501 3.5723 -190.37
# - adjclosebondlag3_return   1  0.289131 3.6950 -187.81
#
# Step:  AIC=-194
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag4_return + volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag4_return         1  0.000140 3.4060 -196.00
# - adjclosestocklag4_return  1  0.000316 3.4062 -195.99
# - volume_return             1  0.001508 3.4074 -195.97
# - adjclosebondlag5_return   1  0.002017 3.4079 -195.95
# - volumelag6_return         1  0.005099 3.4109 -195.88
# - adjclosestocklag5_return  1  0.005283 3.4111 -195.88
# - adjclosestocklag3_return  1  0.006093 3.4119 -195.86
# - volumelag1_return         1  0.016333 3.4222 -195.63
# - adjclosestocklag2_return  1  0.027033 3.4329 -195.40
# - adjclosebondlag4_return   1  0.027580 3.4334 -195.38
# - volumelag3_return         1  0.032577 3.4384 -195.28
# - volumelag2_return         1  0.034527 3.4404 -195.23
# - volumelag5_return         1  0.042342 3.4482 -195.06
# - adjclosebond_return       1  0.047420 3.4533 -194.95
# - adjclosebondlag6_return   1  0.089038 3.4949 -194.04
# <none>                                  3.4058 -194.00
# - adjclosebondlag2_return   1  0.090980 3.4968 -194.00
# - adjclosebondlag1_return   1  0.093048 3.4989 -193.95
# - adjclosestocklag6_return  1  0.111577 3.5174 -193.55
# - adjclosestocklag1_return  1  0.184232 3.5901 -192.00
# - adjclosebondlag3_return   1  0.289147 3.6950 -189.81
#
# Step:  AIC=-196
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag4_return  1  0.000751 3.4067 -197.98
# - volume_return             1  0.001599 3.4076 -197.96
# - adjclosebondlag5_return   1  0.001970 3.4080 -197.95
# - adjclosestocklag5_return  1  0.005343 3.4113 -197.88
# - volumelag6_return         1  0.005726 3.4117 -197.87
# - adjclosestocklag3_return  1  0.007103 3.4131 -197.84
# - volumelag1_return         1  0.016229 3.4222 -197.63
# - adjclosestocklag2_return  1  0.026894 3.4329 -197.40
# - adjclosebondlag4_return   1  0.028858 3.4348 -197.35
# - volumelag2_return         1  0.036719 3.4427 -197.18
# - volumelag3_return         1  0.041856 3.4478 -197.07
# - adjclosebond_return       1  0.047338 3.4533 -196.95
# - volumelag5_return         1  0.057306 3.4633 -196.73
# <none>                                  3.4060 -196.00
# - adjclosebondlag2_return   1  0.090879 3.4969 -195.99
# - adjclosebondlag1_return   1  0.092994 3.4990 -195.95
# - adjclosebondlag6_return   1  0.095509 3.5015 -195.89
# - adjclosestocklag6_return  1  0.112098 3.5181 -195.53
# - adjclosestocklag1_return  1  0.184911 3.5909 -193.98
# - adjclosebondlag3_return   1  0.291451 3.6974 -191.75
#
# Step:  AIC=-197.98
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag2_return + volumelag3_return + volumelag5_return +
#     volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag5_return   1  0.002078 3.4088 -199.93
# - volume_return             1  0.002310 3.4090 -199.93
# - adjclosestocklag5_return  1  0.006259 3.4130 -199.84
# - volumelag6_return         1  0.006433 3.4132 -199.84
# - adjclosestocklag3_return  1  0.006439 3.4132 -199.84
# - volumelag1_return         1  0.015478 3.4222 -199.63
# - adjclosestocklag2_return  1  0.027242 3.4340 -199.37
# - adjclosebondlag4_return   1  0.029836 3.4366 -199.32
# - volumelag2_return         1  0.038796 3.4455 -199.12
# - volumelag3_return         1  0.043055 3.4498 -199.02
# - adjclosebond_return       1  0.047813 3.4545 -198.92
# - volumelag5_return         1  0.056595 3.4633 -198.73
# <none>                                  3.4067 -197.98
# - adjclosebondlag2_return   1  0.091401 3.4981 -197.97
# - adjclosebondlag1_return   1  0.093828 3.5006 -197.91
# - adjclosebondlag6_return   1  0.095200 3.5019 -197.88
# - adjclosestocklag6_return  1  0.111390 3.5181 -197.53
# - adjclosestocklag1_return  1  0.189396 3.5961 -195.87
# - adjclosebondlag3_return   1  0.296847 3.7036 -193.63
#
# Step:  AIC=-199.93
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume_return + volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volume_return             1  0.001956 3.4108 -201.89
# - volumelag6_return         1  0.006620 3.4154 -201.78
# - adjclosestocklag5_return  1  0.006634 3.4154 -201.78
# - adjclosestocklag3_return  1  0.007378 3.4162 -201.77
# - volumelag1_return         1  0.014530 3.4233 -201.61
# - adjclosestocklag2_return  1  0.025972 3.4348 -201.35
# - adjclosebondlag4_return   1  0.027982 3.4368 -201.31
# - volumelag3_return         1  0.040979 3.4498 -201.02
# - volumelag2_return         1  0.041032 3.4498 -201.02
# - adjclosebond_return       1  0.052848 3.4617 -200.76
# - volumelag5_return         1  0.055232 3.4640 -200.71
# <none>                                  3.4088 -199.93
# - adjclosebondlag2_return   1  0.091843 3.5007 -199.91
# - adjclosebondlag6_return   1  0.093148 3.5020 -199.88
# - adjclosebondlag1_return   1  0.096540 3.5054 -199.81
# - adjclosestocklag6_return  1  0.109434 3.5182 -199.53
# - adjclosestocklag1_return  1  0.200695 3.6095 -197.58
# - adjclosebondlag3_return   1  0.297661 3.7065 -195.57
#
# Step:  AIC=-201.89
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag6_return         1  0.005710 3.4165 -203.76
# - adjclosestocklag5_return  1  0.006199 3.4170 -203.75
# - adjclosestocklag3_return  1  0.007882 3.4187 -203.71
# - adjclosebondlag4_return   1  0.026965 3.4377 -203.29
# - adjclosestocklag2_return  1  0.027360 3.4381 -203.28
# - volumelag1_return         1  0.029597 3.4404 -203.23
# - volumelag2_return         1  0.039119 3.4499 -203.02
# - volumelag3_return         1  0.039994 3.4508 -203.00
# - adjclosebond_return       1  0.059803 3.4706 -202.57
# - volumelag5_return         1  0.060491 3.4713 -202.55
# <none>                                  3.4108 -201.89
# - adjclosebondlag6_return   1  0.095235 3.5060 -201.79
# - adjclosebondlag1_return   1  0.098331 3.5091 -201.73
# - adjclosebondlag2_return   1  0.102875 3.5136 -201.63
# - adjclosestocklag6_return  1  0.107616 3.5184 -201.53
# - adjclosestocklag1_return  1  0.205194 3.6160 -199.45
# - adjclosebondlag3_return   1  0.300463 3.7112 -197.47
#
# Step:  AIC=-203.76
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag3_return  1  0.009554 3.4260 -205.55
# - adjclosestocklag5_return  1  0.009993 3.4265 -205.54
# - adjclosebondlag4_return   1  0.026364 3.4428 -205.18
# - adjclosestocklag2_return  1  0.029219 3.4457 -205.11
# - volumelag1_return         1  0.030123 3.4466 -205.09
# - volumelag3_return         1  0.035515 3.4520 -204.97
# - volumelag2_return         1  0.037654 3.4541 -204.93
# - adjclosebond_return       1  0.062527 3.4790 -204.38
# <none>                                  3.4165 -203.76
# - adjclosebondlag6_return   1  0.093141 3.5096 -203.72
# - adjclosebondlag1_return   1  0.094809 3.5113 -203.68
# - adjclosebondlag2_return   1  0.102202 3.5187 -203.52
# - adjclosestocklag6_return  1  0.111920 3.5284 -203.31
# - volumelag5_return         1  0.112447 3.5289 -203.30
# - adjclosestocklag1_return  1  0.226832 3.6433 -200.88
# - adjclosebondlag3_return   1  0.308052 3.7245 -199.20
#
# Step:  AIC=-205.55
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosebondlag4_return + adjclosestocklag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volumelag1_return +
#     volumelag2_return + volumelag3_return + volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag5_return  1  0.008648 3.4347 -207.36
# - adjclosebondlag4_return   1  0.024476 3.4505 -207.01
# - volumelag2_return         1  0.028822 3.4549 -206.91
# - volumelag1_return         1  0.035224 3.4613 -206.77
# - adjclosestocklag2_return  1  0.047527 3.4736 -206.50
# - adjclosebond_return       1  0.059649 3.4857 -206.24
# - volumelag3_return         1  0.071638 3.4977 -205.98
# - adjclosebondlag6_return   1  0.088208 3.5142 -205.62
# - adjclosebondlag1_return   1  0.090825 3.5169 -205.56
# <none>                                  3.4260 -205.55
# - adjclosebondlag2_return   1  0.098914 3.5249 -205.39
# - volumelag5_return         1  0.104390 3.5304 -205.27
# - adjclosestocklag6_return  1  0.125834 3.5519 -204.81
# - adjclosestocklag1_return  1  0.218703 3.6447 -202.85
# - adjclosebondlag3_return   1  0.304564 3.7306 -201.08
#
# Step:  AIC=-207.36
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosebondlag4_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag1_return + volumelag2_return +
#     volumelag3_return + volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag4_return   1  0.022245 3.4569 -208.87
# - volumelag2_return         1  0.022826 3.4575 -208.85
# - volumelag1_return         1  0.040543 3.4752 -208.47
# - adjclosestocklag2_return  1  0.055373 3.4901 -208.14
# - adjclosebond_return       1  0.058694 3.4934 -208.07
# - volumelag3_return         1  0.087149 3.5218 -207.45
# - adjclosebondlag6_return   1  0.089176 3.5239 -207.41
# <none>                                  3.4347 -207.36
# - adjclosebondlag1_return   1  0.094510 3.5292 -207.29
# - volumelag5_return         1  0.097187 3.5319 -207.24
# - adjclosebondlag2_return   1  0.102137 3.5368 -207.13
# - adjclosestocklag6_return  1  0.146490 3.5812 -206.18
# - adjclosestocklag1_return  1  0.218077 3.6528 -204.68
# - adjclosebondlag3_return   1  0.306801 3.7415 -202.85
#
# Step:  AIC=-208.87
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag2_return         1   0.01746 3.4744 -210.48
# - volumelag1_return         1   0.04206 3.4990 -209.95
# - adjclosebond_return       1   0.05960 3.5165 -209.57
# - adjclosestocklag2_return  1   0.06091 3.5178 -209.54
# - volumelag3_return         1   0.08537 3.5423 -209.01
# - adjclosebondlag1_return   1   0.09197 3.5489 -208.87
# <none>                                  3.4569 -208.87
# - adjclosebondlag6_return   1   0.09309 3.5500 -208.85
# - adjclosebondlag2_return   1   0.09959 3.5565 -208.71
# - volumelag5_return         1   0.10499 3.5619 -208.59
# - adjclosestocklag6_return  1   0.14242 3.5993 -207.80
# - adjclosestocklag1_return  1   0.21176 3.6687 -206.35
# - adjclosebondlag3_return   1   0.35033 3.8073 -203.53
#
# Step:  AIC=-210.48
# grade10price_return ~ adjclosebond_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosestocklag2_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag3_return + volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebond_return       1   0.05694 3.5313 -211.25
# - adjclosebondlag1_return   1   0.08509 3.5595 -210.65
# - adjclosebondlag6_return   1   0.09058 3.5650 -210.53
# <none>                                  3.4744 -210.48
# - volumelag5_return         1   0.09903 3.5734 -210.35
# - volumelag1_return         1   0.10786 3.5822 -210.16
# - adjclosebondlag2_return   1   0.10960 3.5840 -210.12
# - adjclosestocklag2_return  1   0.12272 3.5971 -209.85
# - adjclosestocklag6_return  1   0.16318 3.6376 -209.00
# - volumelag3_return         1   0.17441 3.6488 -208.76
# - adjclosestocklag1_return  1   0.19619 3.6706 -208.31
# - adjclosebondlag3_return   1   0.33850 3.8129 -205.42
#
# Step:  AIC=-211.25
# grade10price_return ~ adjclosestocklag1_return + adjclosebondlag1_return +
#     adjclosestocklag2_return + adjclosebondlag2_return + adjclosebondlag3_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volumelag1_return +
#     volumelag3_return + volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag1_return   1   0.06936 3.6007 -211.77
# - volumelag5_return         1   0.08529 3.6166 -211.44
# - adjclosebondlag6_return   1   0.08833 3.6197 -211.37
# <none>                                  3.5313 -211.25
# - volumelag1_return         1   0.09940 3.6307 -211.14
# - adjclosestocklag2_return  1   0.10978 3.6411 -210.92
# - adjclosebondlag2_return   1   0.12097 3.6523 -210.69
# - adjclosestocklag6_return  1   0.16338 3.6947 -209.81
# - volumelag3_return         1   0.17443 3.7058 -209.58
# - adjclosestocklag1_return  1   0.18018 3.7115 -209.47
# - adjclosebondlag3_return   1   0.34719 3.8785 -206.12
#
# Step:  AIC=-211.77
# grade10price_return ~ adjclosestocklag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag1_return + volumelag3_return +
#     volumelag5_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag5_return         1   0.08344 3.6841 -212.03
# - adjclosestocklag2_return  1   0.08729 3.6880 -211.95
# <none>                                  3.6007 -211.77
# - adjclosebondlag2_return   1   0.09681 3.6975 -211.75
# - adjclosebondlag6_return   1   0.11910 3.7198 -211.30
# - volumelag1_return         1   0.12779 3.7285 -211.12
# - volumelag3_return         1   0.16500 3.7657 -210.37
# - adjclosestocklag6_return  1   0.16863 3.7693 -210.29
# - adjclosestocklag1_return  1   0.18253 3.7832 -210.01
# - adjclosebondlag3_return   1   0.35356 3.9542 -206.65
#
# Step:  AIC=-212.03
# grade10price_return ~ adjclosestocklag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag2_return  1   0.07466 3.7588 -212.50
# - volumelag1_return         1   0.08526 3.7694 -212.29
# <none>                                  3.6841 -212.03
# - adjclosebondlag2_return   1   0.10520 3.7893 -211.89
# - adjclosebondlag6_return   1   0.11018 3.7943 -211.79
# - volumelag3_return         1   0.16115 3.8453 -210.78
# - adjclosestocklag6_return  1   0.17335 3.8575 -210.53
# - adjclosestocklag1_return  1   0.22613 3.9103 -209.50
# - adjclosebondlag3_return   1   0.35594 4.0401 -207.02
#
# Step:  AIC=-212.5
# grade10price_return ~ adjclosestocklag1_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag1_return         1   0.06558 3.8244 -213.19
# <none>                                  3.7588 -212.50
# - adjclosebondlag2_return   1   0.11420 3.8730 -212.23
# - adjclosebondlag6_return   1   0.15293 3.9117 -211.47
# - adjclosestocklag6_return  1   0.17248 3.9313 -211.09
# - volumelag3_return         1   0.18393 3.9427 -210.87
# - adjclosestocklag1_return  1   0.31997 4.0788 -208.30
# - adjclosebondlag3_return   1   0.37314 4.1319 -207.31
#
# Step:  AIC=-213.19
# grade10price_return ~ adjclosestocklag1_return + adjclosebondlag2_return +
#     adjclosebondlag3_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# <none>                                  3.8244 -213.19
# - adjclosebondlag2_return   1   0.13777 3.9621 -212.50
# - adjclosebondlag6_return   1   0.15121 3.9756 -212.24
# - adjclosestocklag6_return  1   0.15560 3.9800 -212.16
# - volumelag3_return         1   0.18020 4.0046 -211.69
# - adjclosebondlag3_return   1   0.47655 4.3009 -206.26
# - adjclosestocklag1_return  1   0.49623 4.3206 -205.92
# Call:
# lm(formula = grade10price_return ~ adjclosestocklag1_return +
#     adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag3_return, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.66207 -0.12762 -0.00836  0.13727  0.66772
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               0.02367    0.02806   0.844  0.40184
# adjclosestocklag1_return -1.69056    0.56499  -2.992  0.00384 **
# adjclosebondlag2_return   0.49104    0.31145   1.577  0.11946
# adjclosebondlag3_return  -0.90947    0.31016  -2.932  0.00456 **
# adjclosestocklag6_return -0.95759    0.57153  -1.676  0.09836 .
# adjclosebondlag6_return  -0.51662    0.31277  -1.652  0.10314
# volumelag3_return         0.30851    0.17110   1.803  0.07574 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2354 on 69 degrees of freedom
# Multiple R-squared:  0.279,	Adjusted R-squared:  0.2163
# F-statistic:  4.45 on 6 and 69 DF,  p-value: 0.0007315

# %% [markdown]
# ## Models

# %% [markdown]
# ### OLS

# %%
#OLS
ols_model <- lm(grade10price_return ~ adjclosestocklag1_return + 
    adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return + 
    adjclosebondlag6_return + volumelag3_return , data = df) 

print(summary(ols_model))

library(car)

# Calculate VIF
vif_result <- vif(ols_model)
print(vif_result)

library(lmtest)

# Perform the Breusch-Pagan test
bp_test <- bptest(ols_model)

# Print the test results
print(bp_test)
# Out:
# Call:
# lm(formula = grade10price_return ~ adjclosestocklag1_return +
#     adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag3_return, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.66207 -0.12762 -0.00836  0.13727  0.66772
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               0.02367    0.02806   0.844  0.40184
# adjclosestocklag1_return -1.69056    0.56499  -2.992  0.00384 **
# adjclosebondlag2_return   0.49104    0.31145   1.577  0.11946
# adjclosebondlag3_return  -0.90947    0.31016  -2.932  0.00456 **
# adjclosestocklag6_return -0.95759    0.57153  -1.676  0.09836 .
# adjclosebondlag6_return  -0.51662    0.31277  -1.652  0.10314
# volumelag3_return         0.30851    0.17110   1.803  0.07574 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2354 on 69 degrees of freedom
# Multiple R-squared:  0.279,	Adjusted R-squared:  0.2163
# F-statistic:  4.45 on 6 and 69 DF,  p-value: 0.0007315
# Warning message:
# "package 'car' was built under R version 3.6.3"Loading required package: carData
# adjclosestocklag1_return  adjclosebondlag2_return  adjclosebondlag3_return
#                 1.037512                 1.039376                 1.039695
# adjclosestocklag6_return  adjclosebondlag6_return        volumelag3_return
#                 1.008832                 1.033007                 1.035073
#
# 	studentized Breusch-Pagan test
#
# data:  ols_model
# BP = 5.6376, df = 6, p-value = 0.465

# %% [markdown]
# No heteroskedasticity nor multicollinearity

# %% [markdown]
# ### Quantile regression

# %%
#Quantile regression
library(quantreg)

quantile_model <- rq(grade10price_return ~ adjclosestocklag1_return + 
    adjclosebondlag2_return + adjclosebondlag3_return + adjclosestocklag6_return + 
    adjclosebondlag6_return + volumelag3_return, data = df, tau = seq(from=0.05, to=0.95, by=0.05))  #change tau for different quantiles
                                                                                                                                   

#print summary of quantile regression models
for(grade_return in grade_returns) {
  #print(paste("Summary of quantile regression model for:", grade_return))
  #print(summary(quantile_models[[grade_return]]))
}

#uncomment the last two commented rows (in the previous loop) if you want to see the results for quantiles from 0.05 to 0.95, by 0.05 step

# %% [markdown]
# #### Results for different quantiles of the grade 10 prices x OLS estimates (red line)

# %%
plot(summary(quantile_model))
# Out:
# Plot with title "volumelag3_return"
