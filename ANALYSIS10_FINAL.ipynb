# %% [markdown]
# # Analysis part - Venusaur___Holo_1999_Base_Set

# %%
library(ggplot2)
library(quantreg)


df = read.csv('lagged_merged_datasets_final/merged_Venusaur___Holo_1999_Base_Set.csv')

#convert prices to returns
grades <- grep("grade[0-9]+price", names(df), value = TRUE)
grade_returns <- sapply(grades, function(x) paste0(x, "_return"))

for(grade in grades) {
  df[paste(grade, "return", sep = "_")] <- c(NA, diff(log(df[[grade]])))
}

#convert adjclosestock and adjclosebond (including their lags) to returns
stock_bond_cols <- grep("adjclose(stock|bond)(lag[0-9]+)?", names(df), value = TRUE)

for(col in stock_bond_cols) {
  df[paste0(col, "_return")] <- c(NA, diff(log(df[[col]])))
}


#convert volume and its lags to 'returns'
volume_cols <- grep("volume(lag[0-9]+)?", names(df), value = TRUE)

for(col in volume_cols) {
  df[paste0(col, "_return")] <- c(NA, diff(log(df[[col]])))  # Adding 1 to avoid log(0) issues
}

#remove rows with NA in the newly created return columns
df <- na.omit(df)

print(head(df))
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Warning message:
# "package 'quantreg' was built under R version 3.6.3"Loading required package: SparseM
# Warning message:
# "package 'SparseM' was built under R version 3.6.3"
# Attaching package: 'SparseM'
#
# The following object is masked from 'package:base':
#
#     backsolve
#         date grade6price grade7price grade8price grade9price grade10price
# 2 2016-10-01        16.5        20.5      31.000    60.00000       112.50
# 3 2016-11-01        20.0        20.5      32.000    59.95000       112.50
# 4 2016-12-01        20.0        20.5      22.500    46.00000       112.50
# 5 2017-01-01        20.0        20.5      23.375    56.00000       112.50
# 6 2017-02-01        20.0        20.5      23.375    40.54250       132.44
# 7 2017-03-01        20.0        20.5      23.375    44.66667       122.50
#   adjclosestock      volume adjclosebond  stockreturns bondadjusted
# 2       2126.15 72915530000        2.589 -0.0194256789      0.02589
# 3       2198.81 88445380000        3.017  0.0341745218      0.03017
# 4       2238.83 75344550000        3.063  0.0182007624      0.03063
# 5       2278.87 70576420000        3.051  0.0178843582      0.03051
# 6       2363.64 69260940000        2.968  0.0371981601      0.02968
# 7       2362.72 81664010000        3.018 -0.0003891971      0.03018
#   excessreturns adjclosestocklag1 adjclosebondlag1  volumelag1
# 2  -0.127730484           2168.27            2.336 77023620000
# 3  -0.131140262           2126.15            2.589 72915530000
# 4   0.002953827           2198.81            3.017 88445380000
# 5   0.021802036           2238.83            3.063 75344550000
# 6   0.064402414           2278.87            3.051 70576420000
# 7  -0.017235543           2363.64            2.968 69260940000
#   adjclosestocklag2 adjclosebondlag2  volumelag2 adjclosestocklag3
# 2           2170.95            2.231 75610310000           2173.60
# 3           2168.27            2.336 77023620000           2170.95
# 4           2126.15            2.589 72915530000           2168.27
# 5           2198.81            3.017 88445380000           2126.15
# 6           2238.83            3.063 75344550000           2198.81
# 7           2278.87            3.051 70576420000           2238.83
#   adjclosebondlag3  volumelag3 adjclosestocklag4 adjclosebondlag4  volumelag4
# 2            2.182 69530250000           2098.86            2.307 86852700000
# 3            2.231 75610310000           2173.60            2.182 69530250000
# 4            2.336 77023620000           2170.95            2.231 75610310000
# 5            2.589 72915530000           2168.27            2.336 77023620000
# 6            3.017 88445380000           2126.15            2.589 72915530000
# 7            3.063 75344550000           2198.81            3.017 88445380000
#   adjclosestocklag5 adjclosebondlag5  volumelag5 adjclosestocklag6
# 2           2096.95            2.629 78883600000           2065.30
# 3           2098.86            2.307 86852700000           2096.95
# 4           2173.60            2.182 69530250000           2098.86
# 5           2170.95            2.231 75610310000           2173.60
# 6           2168.27            2.336 77023620000           2170.95
# 7           2126.15            2.589 72915530000           2168.27
#   adjclosebondlag6  volumelag6 grade6price_return grade7price_return
# 2            2.666 81124990000         -0.1918718                  0
# 3            2.629 78883600000          0.1923719                  0
# 4            2.307 86852700000          0.0000000                  0
# 5            2.182 69530250000          0.0000000                  0
# 6            2.231 75610310000          0.0000000                  0
# 7            2.336 77023620000          0.0000000                  0
#   grade8price_return grade9price_return grade10price_return
# 2         0.00000000      -0.4382549309          0.00000000
# 3         0.03174870      -0.0008336807          0.00000000
# 4        -0.35222059      -0.2648694850          0.00000000
# 5         0.03815177       0.1967102942          0.00000000
# 6         0.00000000      -0.3230008841          0.16317649
# 7         0.00000000       0.0968767047         -0.07801868
#   adjclosestock_return adjclosebond_return adjclosestocklag1_return
# 2        -0.0196168370         0.102831645             -0.001235214
# 3         0.0336035450         0.152991251             -0.019616837
# 4         0.0180371113         0.015131869              0.033603545
# 5         0.0177263146        -0.003925372              0.018037111
# 6         0.0365230007        -0.027581141              0.017726315
# 7        -0.0003892729         0.016706020              0.036523001
#   adjclosebondlag1_return adjclosestocklag2_return adjclosebondlag2_return
# 2             0.045990159             -0.001219987             0.022208040
# 3             0.102831645             -0.001235214             0.045990159
# 4             0.152991251             -0.019616837             0.102831645
# 5             0.015131869              0.033603545             0.152991251
# 6            -0.003925372              0.018037111             0.015131869
# 7            -0.027581141              0.017726315            -0.003925372
#   adjclosestocklag3_return adjclosebondlag3_return adjclosestocklag4_return
# 2              0.034990433             -0.05570609             0.0009105066
# 3             -0.001219987              0.02220804             0.0349904327
# 4             -0.001235214              0.04599016            -0.0012199868
# 5             -0.019616837              0.10283165            -0.0012352137
# 6              0.033603545              0.15299125            -0.0196168370
# 7              0.018037111              0.01513187             0.0336035450
#   adjclosebondlag4_return adjclosestocklag5_return adjclosebondlag5_return
# 2             -0.13065558             0.0152083668             -0.01397565
# 3             -0.05570609             0.0009105066             -0.13065558
# 4              0.02220804             0.0349904327             -0.05570609
# 5              0.04599016            -0.0012199868              0.02220804
# 6              0.10283165            -0.0012352137              0.04599016
# 7              0.15299125            -0.0196168370              0.10283165
#   adjclosestocklag6_return adjclosebondlag6_return volume_return
# 2             0.0026957615              0.01740491   -0.05481048
# 3             0.0152083668             -0.01397565    0.19308354
# 4             0.0009105066             -0.13065558   -0.16031359
# 5             0.0349904327             -0.05570609   -0.06537550
# 6            -0.0012199868              0.02220804   -0.01881498
# 7            -0.0012352137              0.04599016    0.16473228
#   volumelag1_return volumelag2_return volumelag3_return volumelag4_return
# 2        0.01851948        0.08383074       -0.22245167        0.09624023
# 3       -0.05481048        0.01851948        0.08383074       -0.22245167
# 4        0.19308354       -0.05481048        0.01851948        0.08383074
# 5       -0.16031359        0.19308354       -0.05481048        0.01851948
# 6       -0.06537550       -0.16031359        0.19308354       -0.05481048
# 7       -0.01881498       -0.06537550       -0.16031359        0.19308354
#   volumelag5_return volumelag6_return
# 2       -0.02801770       -0.13272370
# 3        0.09624023       -0.02801770
# 4       -0.22245167        0.09624023
# 5        0.08383074       -0.22245167
# 6        0.01851948        0.08383074
# 7       -0.05481048        0.01851948

# %%
createReturnsCorrelationMatrix <- function(df) {
  # Load necessary libraries
  library(ggplot2)
  library(reshape2)
  
  # Use a simplified pattern to include both "_return" columns and any "volume" columns
  pattern <- "_return"
  selected_columns <- grep(pattern, names(df), value = TRUE)
  
  # Calculate the correlation matrix for the selected columns
  correlation_matrix <- cor(df[, selected_columns], use = "complete.obs")
  
  # Print the correlation matrix to the console
  print(correlation_matrix)
  
  # Melt the correlation matrix for visualization
  melted_correlation_matrix <- melt(correlation_matrix)
  
  # Create the ggplot object for the correlation matrix
  plot <- ggplot(data = melted_correlation_matrix, aes(x=Var1, y=Var2, fill=value)) +
    geom_tile() +
    scale_fill_gradient2(midpoint=0, low="blue", high="red", mid="white") +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    labs(x='', y='', title='Correlation Matrix of Returns', fill='Correlation')
  
  # Explicitly print the ggplot object to ensure it's displayed
  print(plot)
  
  # Return the correlation matrix as well
  return(correlation_matrix)
}

# Assuming your adjusted dataset is in 'df'
# Example usage:
correlation_matrix <- createReturnsCorrelationMatrix(df)
# Out:
#                          grade6price_return grade7price_return
# grade6price_return              1.000000000        0.274385175
# grade7price_return              0.274385175        1.000000000
# grade8price_return              0.358675352        0.186705976
# grade9price_return              0.384043587        0.183059661
# grade10price_return             0.095494172        0.181900961
# adjclosestock_return           -0.023907624       -0.038740989
# adjclosebond_return             0.169614276       -0.029163415
# adjclosestocklag1_return       -0.205719644       -0.010159543
# adjclosebondlag1_return         0.073541793       -0.105185488
# adjclosestocklag2_return        0.147515238        0.060754729
# adjclosebondlag2_return         0.010305900        0.106332124
# adjclosestocklag3_return        0.129250106       -0.060497096
# adjclosebondlag3_return        -0.189299605       -0.218327142
# adjclosestocklag4_return       -0.118044199       -0.164464955
# adjclosebondlag4_return        -0.005923828       -0.132006695
# adjclosestocklag5_return        0.067653208        0.060794606
# adjclosebondlag5_return         0.111794161        0.111823321
# adjclosestocklag6_return        0.036432486        0.119833970
# adjclosebondlag6_return        -0.153898303       -0.017283076
# volume_return                  -0.071051311        0.043595090
# volumelag1_return               0.170509710        0.001950363
# volumelag2_return              -0.116863220       -0.089348505
# volumelag3_return              -0.067060555        0.147167819
# volumelag4_return               0.127078905       -0.095389941
# volumelag5_return               0.036928798        0.138032785
# volumelag6_return              -0.174397281       -0.045000453
#                          grade8price_return grade9price_return
# grade6price_return              0.358675352        0.384043587
# grade7price_return              0.186705976        0.183059661
# grade8price_return              1.000000000        0.447854060
# grade9price_return              0.447854060        1.000000000
# grade10price_return             0.343414588        0.270849146
# adjclosestock_return           -0.027533096       -0.158035726
# adjclosebond_return            -0.006344116       -0.055588696
# adjclosestocklag1_return       -0.075356844       -0.190443062
# adjclosebondlag1_return        -0.171498480       -0.066101575
# adjclosestocklag2_return        0.090087747        0.171428872
# adjclosebondlag2_return        -0.060082124        0.001989741
# adjclosestocklag3_return        0.019460749        0.029885694
# adjclosebondlag3_return        -0.275656162       -0.344793077
# adjclosestocklag4_return       -0.153579707       -0.039208709
# adjclosebondlag4_return        -0.114262269       -0.082409232
# adjclosestocklag5_return        0.083569975        0.032989592
# adjclosebondlag5_return         0.023941075        0.169660995
# adjclosestocklag6_return        0.177677291        0.035771462
# adjclosebondlag6_return         0.065090437       -0.152807965
# volume_return                  -0.002072141        0.084319943
# volumelag1_return               0.141512593        0.004599311
# volumelag2_return              -0.095713839       -0.065368692
# volumelag3_return               0.019769864       -0.097176110
# volumelag4_return               0.090597483        0.222091836
# volumelag5_return              -0.064051359       -0.005538202
# volumelag6_return               0.014994747       -0.155578122
#                          grade10price_return adjclosestock_return
# grade6price_return                0.09549417          -0.02390762
# grade7price_return                0.18190096          -0.03874099
# grade8price_return                0.34341459          -0.02753310
# grade9price_return                0.27084915          -0.15803573
# grade10price_return               1.00000000          -0.09765506
# adjclosestock_return             -0.09765506           1.00000000
# adjclosebond_return               0.04428351           0.01943513
# adjclosestocklag1_return          0.07911874          -0.18885444
# adjclosebondlag1_return          -0.08037951          -0.01664770
# adjclosestocklag2_return         -0.03226234          -0.08077390
# adjclosebondlag2_return           0.03857739          -0.01642701
# adjclosestocklag3_return          0.17990458           0.04621430
# adjclosebondlag3_return          -0.22517028          -0.03801210
# adjclosestocklag4_return         -0.08126067          -0.01087654
# adjclosebondlag4_return          -0.18316586          -0.14434265
# adjclosestocklag5_return         -0.09293068          -0.01282956
# adjclosebondlag5_return          -0.21306975          -0.15389071
# adjclosestocklag6_return          0.08297332          -0.10682487
# adjclosebondlag6_return           0.01428304           0.10937735
# volume_return                     0.05774349          -0.34030115
# volumelag1_return                -0.10966947           0.05638603
# volumelag2_return                 0.02837750           0.10613559
# volumelag3_return                 0.08717044          -0.03397072
# volumelag4_return                -0.04710519          -0.06635670
# volumelag5_return                 0.07409142           0.23355044
# volumelag6_return                -0.03078595          -0.10577887
#                          adjclosebond_return adjclosestocklag1_return
# grade6price_return              0.1696142759             -0.205719644
# grade7price_return             -0.0291634151             -0.010159543
# grade8price_return             -0.0063441162             -0.075356844
# grade9price_return             -0.0555886956             -0.190443062
# grade10price_return             0.0442835113              0.079118737
# adjclosestock_return            0.0194351268             -0.188854437
# adjclosebond_return             1.0000000000              0.119599668
# adjclosestocklag1_return        0.1195996683              1.000000000
# adjclosebondlag1_return         0.1606092870              0.024037342
# adjclosestocklag2_return       -0.0857994055             -0.184242621
# adjclosebondlag2_return         0.0805596072             -0.022313062
# adjclosestocklag3_return        0.0267889389             -0.090427225
# adjclosebondlag3_return        -0.0105958364             -0.007579837
# adjclosestocklag4_return       -0.0810632855              0.057603507
# adjclosebondlag4_return        -0.0519376878             -0.036410993
# adjclosestocklag5_return        0.0062122047             -0.017944919
# adjclosebondlag5_return         0.0855527242             -0.137158650
# adjclosestocklag6_return       -0.0008449803             -0.023341255
# adjclosebondlag6_return         0.0142388680             -0.164388637
# volume_return                  -0.1339820110             -0.058479917
# volumelag1_return              -0.0812192749             -0.365972767
# volumelag2_return               0.0616100245              0.055377188
# volumelag3_return               0.0069156403              0.110885048
# volumelag4_return               0.0298441820             -0.031763509
# volumelag5_return              -0.0716163397             -0.064457646
# volumelag6_return               0.0011938591              0.234283914
#                          adjclosebondlag1_return adjclosestocklag2_return
# grade6price_return                   0.073541793              0.147515238
# grade7price_return                  -0.105185488              0.060754729
# grade8price_return                  -0.171498480              0.090087747
# grade9price_return                  -0.066101575              0.171428872
# grade10price_return                 -0.080379514             -0.032262338
# adjclosestock_return                -0.016647696             -0.080773899
# adjclosebond_return                  0.160609287             -0.085799406
# adjclosestocklag1_return             0.024037342             -0.184242621
# adjclosebondlag1_return              1.000000000              0.111902818
# adjclosestocklag2_return             0.111902818              1.000000000
# adjclosebondlag2_return              0.170040200              0.030476549
# adjclosestocklag3_return            -0.072138592             -0.177213715
# adjclosebondlag3_return              0.066557072             -0.030060069
# adjclosestocklag4_return             0.011415758             -0.104969666
# adjclosebondlag4_return             -0.015468267             -0.000298199
# adjclosestocklag5_return            -0.071292435              0.066364338
# adjclosebondlag5_return             -0.065417889             -0.046761857
# adjclosestocklag6_return             0.021008839             -0.004247759
# adjclosebondlag6_return              0.099661859             -0.128125984
# volume_return                        0.089742367              0.126954169
# volumelag1_return                   -0.115856741             -0.040997713
# volumelag2_return                   -0.078705686             -0.368065004
# volumelag3_return                    0.049592508              0.055146037
# volumelag4_return                    0.004977328              0.104908010
# volumelag5_return                    0.026596817             -0.033435527
# volumelag6_return                   -0.075285036             -0.061472798
#                          adjclosebondlag2_return adjclosestocklag3_return
# grade6price_return                   0.010305900               0.12925011
# grade7price_return                   0.106332124              -0.06049710
# grade8price_return                  -0.060082124               0.01946075
# grade9price_return                   0.001989741               0.02988569
# grade10price_return                  0.038577393               0.17990458
# adjclosestock_return                -0.016427015               0.04621430
# adjclosebond_return                  0.080559607               0.02678894
# adjclosestocklag1_return            -0.022313062              -0.09042723
# adjclosebondlag1_return              0.170040200              -0.07213859
# adjclosestocklag2_return             0.030476549              -0.17721372
# adjclosebondlag2_return              1.000000000               0.10393276
# adjclosestocklag3_return             0.103932755               1.00000000
# adjclosebondlag3_return              0.179124672               0.03977537
# adjclosestocklag4_return            -0.059969985              -0.16128291
# adjclosebondlag4_return              0.058857154              -0.04623054
# adjclosestocklag5_return             0.003025567              -0.11819040
# adjclosebondlag5_return             -0.005416347               0.01405834
# adjclosestocklag6_return            -0.086834214               0.04597958
# adjclosebondlag6_return             -0.077210183              -0.06325024
# volume_return                       -0.187644202              -0.02820548
# volumelag1_return                    0.072815351               0.10222699
# volumelag2_return                   -0.114521013              -0.03685166
# volumelag3_return                   -0.077929618              -0.37110471
# volumelag4_return                    0.055974669               0.06706853
# volumelag5_return                    0.006650307               0.10722299
# volumelag6_return                    0.023818439              -0.04084433
#                          adjclosebondlag3_return adjclosestocklag4_return
# grade6price_return                  -0.189299605              -0.11804420
# grade7price_return                  -0.218327142              -0.16446495
# grade8price_return                  -0.275656162              -0.15357971
# grade9price_return                  -0.344793077              -0.03920871
# grade10price_return                 -0.225170275              -0.08126067
# adjclosestock_return                -0.038012101              -0.01087654
# adjclosebond_return                 -0.010595836              -0.08106329
# adjclosestocklag1_return            -0.007579837               0.05760351
# adjclosebondlag1_return              0.066557072               0.01141576
# adjclosestocklag2_return            -0.030060069              -0.10496967
# adjclosebondlag2_return              0.179124672              -0.05996998
# adjclosestocklag3_return             0.039775372              -0.16128291
# adjclosebondlag3_return              1.000000000               0.08799390
# adjclosestocklag4_return             0.087993902               1.00000000
# adjclosebondlag4_return              0.196150465               0.04980743
# adjclosestocklag5_return            -0.049577265              -0.14701471
# adjclosebondlag5_return              0.046619684              -0.06822133
# adjclosestocklag6_return             0.023619834              -0.09317221
# adjclosebondlag6_return              0.008960596               0.03668150
# volume_return                        0.061510156               0.10119247
# volumelag1_return                   -0.166714366               0.01043612
# volumelag2_return                    0.067685820               0.10170011
# volumelag3_return                   -0.105290990              -0.04058456
# volumelag4_return                   -0.090443011              -0.38693277
# volumelag5_return                    0.054997365               0.06419975
# volumelag6_return                    0.015494524               0.11162269
#                          adjclosebondlag4_return adjclosestocklag5_return
# grade6price_return                  -0.005923828              0.067653208
# grade7price_return                  -0.132006695              0.060794606
# grade8price_return                  -0.114262269              0.083569975
# grade9price_return                  -0.082409232              0.032989592
# grade10price_return                 -0.183165857             -0.092930676
# adjclosestock_return                -0.144342652             -0.012829556
# adjclosebond_return                 -0.051937688              0.006212205
# adjclosestocklag1_return            -0.036410993             -0.017944919
# adjclosebondlag1_return             -0.015468267             -0.071292435
# adjclosestocklag2_return            -0.000298199              0.066364338
# adjclosebondlag2_return              0.058857154              0.003025567
# adjclosestocklag3_return            -0.046230544             -0.118190396
# adjclosebondlag3_return              0.196150465             -0.049577265
# adjclosestocklag4_return             0.049807432             -0.147014709
# adjclosebondlag4_return              1.000000000              0.079765874
# adjclosestocklag5_return             0.079765874              1.000000000
# adjclosebondlag5_return              0.204712083              0.063841154
# adjclosestocklag6_return            -0.054698128             -0.168196832
# adjclosebondlag6_return              0.037816595             -0.083473963
# volume_return                       -0.012446032              0.071267575
# volumelag1_return                    0.050129179              0.079124009
# volumelag2_return                   -0.174099662              0.011910640
# volumelag3_return                    0.094991096              0.102554338
# volumelag4_return                   -0.112893684             -0.033337820
# volumelag5_return                   -0.084389459             -0.386788799
# volumelag6_return                    0.069868391              0.061547871
#                          adjclosebondlag5_return adjclosestocklag6_return
# grade6price_return                   0.111794161             0.0364324860
# grade7price_return                   0.111823321             0.1198339705
# grade8price_return                   0.023941075             0.1776772907
# grade9price_return                   0.169660995             0.0357714620
# grade10price_return                 -0.213069746             0.0829733169
# adjclosestock_return                -0.153890706            -0.1068248673
# adjclosebond_return                  0.085552724            -0.0008449803
# adjclosestocklag1_return            -0.137158650            -0.0233412553
# adjclosebondlag1_return             -0.065417889             0.0210088394
# adjclosestocklag2_return            -0.046761857            -0.0042477592
# adjclosebondlag2_return             -0.005416347            -0.0868342145
# adjclosestocklag3_return             0.014058338             0.0459795841
# adjclosebondlag3_return              0.046619684             0.0236198339
# adjclosestocklag4_return            -0.068221332            -0.0931722093
# adjclosebondlag4_return              0.204712083            -0.0546981282
# adjclosestocklag5_return             0.063841154            -0.1681968318
# adjclosebondlag5_return              1.000000000             0.1037999402
# adjclosestocklag6_return             0.103799940             1.0000000000
# adjclosebondlag6_return              0.225481103             0.0420151559
# volume_return                        0.035043708            -0.0240224645
# volumelag1_return                    0.018087042             0.0331975151
# volumelag2_return                    0.048435149             0.0801290679
# volumelag3_return                   -0.174542815             0.0203880349
# volumelag4_return                    0.086351067             0.1132476074
# volumelag5_return                   -0.116522300            -0.0293116542
# volumelag6_return                   -0.080961416            -0.3912992050
#                          adjclosebondlag6_return volume_return
# grade6price_return                  -0.153898303  -0.071051311
# grade7price_return                  -0.017283076   0.043595090
# grade8price_return                   0.065090437  -0.002072141
# grade9price_return                  -0.152807965   0.084319943
# grade10price_return                  0.014283042   0.057743492
# adjclosestock_return                 0.109377351  -0.340301151
# adjclosebond_return                  0.014238868  -0.133982011
# adjclosestocklag1_return            -0.164388637  -0.058479917
# adjclosebondlag1_return              0.099661859   0.089742367
# adjclosestocklag2_return            -0.128125984   0.126954169
# adjclosebondlag2_return             -0.077210183  -0.187644202
# adjclosestocklag3_return            -0.063250237  -0.028205483
# adjclosebondlag3_return              0.008960596   0.061510156
# adjclosestocklag4_return             0.036681503   0.101192465
# adjclosebondlag4_return              0.037816595  -0.012446032
# adjclosestocklag5_return            -0.083473963   0.071267575
# adjclosebondlag5_return              0.225481103   0.035043708
# adjclosestocklag6_return             0.042015156  -0.024022464
# adjclosebondlag6_return              1.000000000   0.123869273
# volume_return                        0.123869273   1.000000000
# volumelag1_return                    0.003599478  -0.409640642
# volumelag2_return                    0.019728626  -0.037180267
# volumelag3_return                    0.051095298   0.170881659
# volumelag4_return                   -0.166885903  -0.240470775
# volumelag5_return                    0.090225511   0.029614687
# volumelag6_return                   -0.120035092  -0.046896794
#                          volumelag1_return volumelag2_return volumelag3_return
# grade6price_return             0.170509710       -0.11686322       -0.06706055
# grade7price_return             0.001950363       -0.08934851        0.14716782
# grade8price_return             0.141512593       -0.09571384        0.01976986
# grade9price_return             0.004599311       -0.06536869       -0.09717611
# grade10price_return           -0.109669469        0.02837750        0.08717044
# adjclosestock_return           0.056386031        0.10613559       -0.03397072
# adjclosebond_return           -0.081219275        0.06161002        0.00691564
# adjclosestocklag1_return      -0.365972767        0.05537719        0.11088505
# adjclosebondlag1_return       -0.115856741       -0.07870569        0.04959251
# adjclosestocklag2_return      -0.040997713       -0.36806500        0.05514604
# adjclosebondlag2_return        0.072815351       -0.11452101       -0.07792962
# adjclosestocklag3_return       0.102226990       -0.03685166       -0.37110471
# adjclosebondlag3_return       -0.166714366        0.06768582       -0.10529099
# adjclosestocklag4_return       0.010436120        0.10170011       -0.04058456
# adjclosebondlag4_return        0.050129179       -0.17409966        0.09499110
# adjclosestocklag5_return       0.079124009        0.01191064        0.10255434
# adjclosebondlag5_return        0.018087042        0.04843515       -0.17454282
# adjclosestocklag6_return       0.033197515        0.08012907        0.02038803
# adjclosebondlag6_return        0.003599478        0.01972863        0.05109530
# volume_return                 -0.409640642       -0.03718027        0.17088166
# volumelag1_return              1.000000000       -0.41900449       -0.03021049
# volumelag2_return             -0.419004487        1.00000000       -0.42280757
# volumelag3_return             -0.030210495       -0.42280757        1.00000000
# volumelag4_return              0.190830844       -0.02644773       -0.43052204
# volumelag5_return             -0.241589361        0.18916491       -0.02377073
# volumelag6_return              0.026658083       -0.24559869        0.20133397
#                          volumelag4_return volumelag5_return volumelag6_return
# grade6price_return             0.127078905       0.036928798      -0.174397281
# grade7price_return            -0.095389941       0.138032785      -0.045000453
# grade8price_return             0.090597483      -0.064051359       0.014994747
# grade9price_return             0.222091836      -0.005538202      -0.155578122
# grade10price_return           -0.047105185       0.074091422      -0.030785953
# adjclosestock_return          -0.066356703       0.233550439      -0.105778867
# adjclosebond_return            0.029844182      -0.071616340       0.001193859
# adjclosestocklag1_return      -0.031763509      -0.064457646       0.234283914
# adjclosebondlag1_return        0.004977328       0.026596817      -0.075285036
# adjclosestocklag2_return       0.104908010      -0.033435527      -0.061472798
# adjclosebondlag2_return        0.055974669       0.006650307       0.023818439
# adjclosestocklag3_return       0.067068527       0.107222990      -0.040844334
# adjclosebondlag3_return       -0.090443011       0.054997365       0.015494524
# adjclosestocklag4_return      -0.386932773       0.064199751       0.111622694
# adjclosebondlag4_return       -0.112893684      -0.084389459       0.069868391
# adjclosestocklag5_return      -0.033337820      -0.386788799       0.061547871
# adjclosebondlag5_return        0.086351067      -0.116522300      -0.080961416
# adjclosestocklag6_return       0.113247607      -0.029311654      -0.391299205
# adjclosebondlag6_return       -0.166885903       0.090225511      -0.120035092
# volume_return                 -0.240470775       0.029614687      -0.046896794
# volumelag1_return              0.190830844      -0.241589361       0.026658083
# volumelag2_return             -0.026447728       0.189164914      -0.245598692
# volumelag3_return             -0.430522040      -0.023770728       0.201333971
# volumelag4_return              1.000000000      -0.433263316      -0.029315970
# volumelag5_return             -0.433263316       1.000000000      -0.429148040
# volumelag6_return             -0.029315970      -0.429148040       1.000000000
# plot without title

# %% [markdown]
# ## VAR model - try later - if enough time...

# %% [markdown]
# ## Visualisation

# %%
#create a long format data frame suitable for faceting with returns
long_df <- reshape2::melt(df, id.vars = "date", measure.vars = grade_returns)

#histograms for card grade returns
p1 <- ggplot(long_df, aes(x = value)) +
  geom_histogram(bins = 30, fill = "blue", alpha = 0.5) +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Returns", y = "Frequency", title = "Histograms of Card Grade Returns - Blastoise 1999")

print(p1)
# Out:
# plot without title

# %%
#histogram of stock returns
p2 <- ggplot(df, aes(x = adjclosestock_return)) +
  geom_histogram(bins = 30, fill = "red", alpha = 0.5) +
  labs(title = "Histogram of Stock Returns (Blastoise 1999)")

print(p2)
# Out:
# plot without title

# %%
#a long format data frame suitable for scatterplots with returns
long_df <- reshape2::melt(df, id.vars = c("date", "adjclosestocklag1_return"), measure.vars = grade_returns) #ADJUST FOR DIFFERENT LAGS

#scatterplots between stock returns and card grades returns
p3 <- ggplot(long_df, aes(x = adjclosestocklag1_return, y = value)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "red") +
  facet_wrap(~ variable, scales = "free") +
  labs(x = "Stock Returns", y = "Card Grade Returns", title = "Scatterplots of Stock Returns vs Card Grade Returns - Blastoise 1999")

print(p3)
# Out:
# plot without title

# %% [markdown]
# ## Choose the variables using AIC

# %%
# Load necessary library
library(stats)

# Preparing the initial full model with the dependent variable (choosing one of the grade prices as an example)
# and all potential independent variables (using returns and lagged returns)
# Note: Adjust 'grade5price' to the specific grade price return you are analyzing
full_model <- lm(grade10price_return ~ adjclosestock_return + adjclosebond_return +
                 adjclosestocklag1_return + adjclosebondlag1_return +
                 adjclosestocklag2_return + adjclosebondlag2_return +
                 adjclosestocklag3_return + adjclosebondlag3_return +
                 adjclosestocklag4_return + adjclosebondlag4_return +
                 adjclosestocklag5_return + adjclosebondlag5_return +
                 adjclosestocklag6_return + adjclosebondlag6_return +
                 volume_return + volumelag1_return + volumelag2_return + volumelag3_return + 
                 volumelag4_return + volumelag5_return + volumelag6_return, data = df)

# Perform backward elimination based on AIC
reduced_model <- step(full_model, direction = "backward")

# Display the summary of the reduced model to see the selected variables and their coefficients
summary(reduced_model)
# Out:
# Start:  AIC=-162.6
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosestocklag2_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosestocklag4_return + adjclosebondlag4_return + adjclosestocklag5_return +
#     adjclosebondlag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume_return + volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag4_return + volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag2_return  1   0.00074 5.5188 -164.59
# - volumelag4_return         1   0.00092 5.5190 -164.59
# - adjclosestocklag4_return  1   0.00128 5.5193 -164.58
# - volumelag5_return         1   0.00324 5.5213 -164.55
# - adjclosestocklag1_return  1   0.00410 5.5221 -164.54
# - volumelag2_return         1   0.00680 5.5248 -164.50
# - volumelag6_return         1   0.00764 5.5257 -164.49
# - adjclosebond_return       1   0.00940 5.5274 -164.47
# - volume_return             1   0.01126 5.5293 -164.44
# - adjclosestocklag6_return  1   0.01157 5.5296 -164.43
# - adjclosestocklag5_return  1   0.01576 5.5338 -164.38
# - volumelag3_return         1   0.06510 5.5831 -163.68
# - adjclosebondlag4_return   1   0.06993 5.5880 -163.62
# - adjclosebondlag6_return   1   0.07474 5.5928 -163.55
# - adjclosebondlag2_return   1   0.07540 5.5934 -163.54
# - volumelag1_return         1   0.08047 5.5985 -163.47
# - adjclosebondlag1_return   1   0.10823 5.6263 -163.08
# <none>                                  5.5180 -162.60
# - adjclosestock_return      1   0.17717 5.6952 -162.13
# - adjclosestocklag3_return  1   0.27551 5.7936 -160.80
# - adjclosebondlag5_return   1   0.30120 5.8192 -160.45
# - adjclosebondlag3_return   1   0.34893 5.8670 -159.81
#
# Step:  AIC=-164.59
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag4_return + volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag4_return         1   0.00098 5.5198 -166.57
# - adjclosestocklag4_return  1   0.00137 5.5202 -166.57
# - volumelag5_return         1   0.00325 5.5220 -166.54
# - adjclosestocklag1_return  1   0.00612 5.5249 -166.50
# - volumelag2_return         1   0.00660 5.5254 -166.49
# - volumelag6_return         1   0.00814 5.5269 -166.47
# - adjclosebond_return       1   0.00915 5.5279 -166.46
# - volume_return             1   0.01203 5.5308 -166.42
# - adjclosestocklag6_return  1   0.01205 5.5308 -166.42
# - adjclosestocklag5_return  1   0.01514 5.5339 -166.37
# - volumelag3_return         1   0.06657 5.5854 -165.65
# - adjclosebondlag4_return   1   0.07207 5.5909 -165.57
# - adjclosebondlag6_return   1   0.07432 5.5931 -165.54
# - adjclosebondlag2_return   1   0.07488 5.5937 -165.54
# - volumelag1_return         1   0.10183 5.6206 -165.16
# - adjclosebondlag1_return   1   0.10769 5.6265 -165.08
# <none>                                  5.5188 -164.59
# - adjclosestock_return      1   0.18129 5.7001 -164.07
# - adjclosestocklag3_return  1   0.29784 5.8166 -162.49
# - adjclosebondlag5_return   1   0.30707 5.8259 -162.36
# - adjclosebondlag3_return   1   0.35302 5.8718 -161.75
#
# Step:  AIC=-166.57
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosestocklag4_return +
#     adjclosebondlag4_return + adjclosestocklag5_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume_return +
#     volumelag1_return + volumelag2_return + volumelag3_return +
#     volumelag5_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag4_return  1   0.00059 5.5204 -168.56
# - volumelag5_return         1   0.00226 5.5220 -168.54
# - adjclosestocklag1_return  1   0.00619 5.5260 -168.49
# - volumelag6_return         1   0.00737 5.5271 -168.47
# - volumelag2_return         1   0.00786 5.5276 -168.46
# - adjclosebond_return       1   0.00956 5.5293 -168.44
# - volume_return             1   0.01143 5.5312 -168.41
# - adjclosestocklag6_return  1   0.01215 5.5319 -168.40
# - adjclosestocklag5_return  1   0.01426 5.5340 -168.37
# - adjclosebondlag4_return   1   0.07109 5.5909 -167.57
# - adjclosebondlag2_return   1   0.07522 5.5950 -167.52
# - adjclosebondlag6_return   1   0.07928 5.5990 -167.46
# - volumelag1_return         1   0.10153 5.6213 -167.15
# - volumelag3_return         1   0.10595 5.6257 -167.09
# - adjclosebondlag1_return   1   0.10846 5.6282 -167.06
# <none>                                  5.5198 -166.57
# - adjclosestock_return      1   0.18163 5.7014 -166.05
# - adjclosebondlag5_return   1   0.30616 5.8259 -164.36
# - adjclosestocklag3_return  1   0.32630 5.8461 -164.09
# - adjclosebondlag3_return   1   0.35234 5.8721 -163.75
#
# Step:  AIC=-168.56
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag2_return + volumelag3_return + volumelag5_return +
#     volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag5_return         1   0.00251 5.5229 -170.53
# - adjclosestocklag1_return  1   0.00689 5.5272 -170.47
# - volumelag2_return         1   0.00733 5.5277 -170.46
# - volumelag6_return         1   0.00825 5.5286 -170.45
# - adjclosebond_return       1   0.00966 5.5300 -170.43
# - adjclosestocklag6_return  1   0.01231 5.5327 -170.39
# - volume_return             1   0.01356 5.5339 -170.37
# - adjclosestocklag5_return  1   0.01369 5.5340 -170.37
# - adjclosebondlag4_return   1   0.07317 5.5935 -169.54
# - adjclosebondlag2_return   1   0.07535 5.5957 -169.51
# - adjclosebondlag6_return   1   0.07924 5.5996 -169.45
# - volumelag3_return         1   0.10829 5.6286 -169.05
# - adjclosebondlag1_return   1   0.10900 5.6294 -169.04
# - volumelag1_return         1   0.11290 5.6333 -168.99
# <none>                                  5.5204 -168.56
# - adjclosestock_return      1   0.18441 5.7048 -168.00
# - adjclosebondlag5_return   1   0.30560 5.8260 -166.36
# - adjclosestocklag3_return  1   0.34876 5.8691 -165.79
# - adjclosebondlag3_return   1   0.35709 5.8774 -165.68
#
# Step:  AIC=-170.53
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag2_return + volumelag3_return + volumelag6_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag6_return         1   0.00575 5.5286 -172.45
# - volumelag2_return         1   0.00654 5.5294 -172.44
# - adjclosestocklag1_return  1   0.00672 5.5296 -172.44
# - adjclosebond_return       1   0.01117 5.5340 -172.37
# - adjclosestocklag5_return  1   0.01120 5.5341 -172.37
# - volume_return             1   0.01293 5.5358 -172.35
# - adjclosestocklag6_return  1   0.01856 5.5414 -172.27
# - adjclosebondlag4_return   1   0.07276 5.5956 -171.51
# - adjclosebondlag2_return   1   0.07463 5.5975 -171.48
# - adjclosebondlag6_return   1   0.07880 5.6017 -171.42
# - volumelag3_return         1   0.10677 5.6296 -171.04
# - adjclosebondlag1_return   1   0.10765 5.6305 -171.02
# - volumelag1_return         1   0.11049 5.6334 -170.98
# <none>                                  5.5229 -170.53
# - adjclosestock_return      1   0.19333 5.7162 -169.85
# - adjclosebondlag5_return   1   0.30347 5.8263 -168.36
# - adjclosestocklag3_return  1   0.35025 5.8731 -167.73
# - adjclosebondlag3_return   1   0.36129 5.8842 -167.59
#
# Step:  AIC=-172.45
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag2_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag2_return         1   0.00835 5.5370 -174.33
# - adjclosestocklag1_return  1   0.00944 5.5381 -174.31
# - adjclosestocklag5_return  1   0.01099 5.5396 -174.29
# - volume_return             1   0.01132 5.5399 -174.29
# - adjclosebond_return       1   0.01143 5.5400 -174.29
# - adjclosestocklag6_return  1   0.03399 5.5626 -173.97
# - adjclosebondlag4_return   1   0.07183 5.6004 -173.44
# - adjclosebondlag2_return   1   0.07684 5.6054 -173.37
# - adjclosebondlag6_return   1   0.08121 5.6098 -173.31
# - volumelag3_return         1   0.10167 5.6303 -173.03
# - adjclosebondlag1_return   1   0.10448 5.6331 -172.99
# - volumelag1_return         1   0.11091 5.6395 -172.90
# <none>                                  5.5286 -172.45
# - adjclosestock_return      1   0.18795 5.7166 -171.84
# - adjclosebondlag5_return   1   0.30504 5.8337 -170.26
# - adjclosestocklag3_return  1   0.34667 5.8753 -169.71
# - adjclosebondlag3_return   1   0.37125 5.8999 -169.38
#
# Step:  AIC=-174.33
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosestocklag5_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag5_return  1   0.00823 5.5452 -176.22
# - adjclosestocklag1_return  1   0.01228 5.5492 -176.16
# - adjclosebond_return       1   0.01228 5.5492 -176.16
# - volume_return             1   0.01649 5.5535 -176.10
# - adjclosestocklag6_return  1   0.04070 5.5777 -175.76
# - adjclosebondlag2_return   1   0.07168 5.6086 -175.33
# - adjclosebondlag4_return   1   0.07974 5.6167 -175.22
# - adjclosebondlag6_return   1   0.08612 5.6231 -175.13
# - volumelag3_return         1   0.09914 5.6361 -174.95
# - adjclosebondlag1_return   1   0.11460 5.6516 -174.73
# <none>                                  5.5370 -174.33
# - adjclosestock_return      1   0.18655 5.7235 -173.75
# - volumelag1_return         1   0.19618 5.7331 -173.62
# - adjclosebondlag5_return   1   0.31294 5.8499 -172.04
# - adjclosestocklag3_return  1   0.33896 5.8759 -171.70
# - adjclosebondlag3_return   1   0.37215 5.9091 -171.26
#
# Step:  AIC=-176.21
# grade10price_return ~ adjclosestock_return + adjclosebond_return +
#     adjclosestocklag1_return + adjclosebondlag1_return + adjclosebondlag2_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosebondlag5_return + adjclosestocklag6_return + adjclosebondlag6_return +
#     volume_return + volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebond_return       1   0.01144 5.5566 -178.05
# - adjclosestocklag1_return  1   0.01302 5.5582 -178.03
# - volume_return             1   0.02036 5.5655 -177.93
# - adjclosestocklag6_return  1   0.04775 5.5929 -177.55
# - adjclosebondlag2_return   1   0.07029 5.6155 -177.23
# - adjclosebondlag4_return   1   0.08272 5.6279 -177.06
# - adjclosebondlag6_return   1   0.09456 5.6398 -176.90
# - volumelag3_return         1   0.09646 5.6417 -176.87
# - adjclosebondlag1_return   1   0.11113 5.6563 -176.67
# <none>                                  5.5452 -176.22
# - adjclosestock_return      1   0.19265 5.7378 -175.55
# - volumelag1_return         1   0.21109 5.7563 -175.30
# - adjclosebondlag5_return   1   0.32715 5.8723 -173.74
# - adjclosestocklag3_return  1   0.35508 5.9003 -173.37
# - adjclosebondlag3_return   1   0.36914 5.9143 -173.19
#
# Step:  AIC=-178.05
# grade10price_return ~ adjclosestock_return + adjclosestocklag1_return +
#     adjclosebondlag1_return + adjclosebondlag2_return + adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag4_return + adjclosebondlag5_return +
#     adjclosestocklag6_return + adjclosebondlag6_return + volume_return +
#     volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag1_return  1   0.01178 5.5684 -179.89
# - volume_return             1   0.02697 5.5836 -179.68
# - adjclosestocklag6_return  1   0.04639 5.6030 -179.41
# - adjclosebondlag2_return   1   0.07179 5.6284 -179.05
# - adjclosebondlag4_return   1   0.08820 5.6448 -178.83
# - adjclosebondlag6_return   1   0.09554 5.6522 -178.72
# - adjclosebondlag1_return   1   0.10236 5.6590 -178.63
# - volumelag3_return         1   0.10249 5.6591 -178.63
# <none>                                  5.5566 -178.05
# - adjclosestock_return      1   0.19544 5.7521 -177.36
# - volumelag1_return         1   0.22528 5.7819 -176.95
# - adjclosebondlag5_return   1   0.31664 5.8733 -175.73
# - adjclosestocklag3_return  1   0.36715 5.9238 -175.06
# - adjclosebondlag3_return   1   0.37194 5.9286 -175.00
#
# Step:  AIC=-179.89
# grade10price_return ~ adjclosestock_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosebondlag4_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volume_return + volumelag1_return +
#     volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - volume_return             1   0.01809 5.5865 -181.64
# - adjclosestocklag6_return  1   0.04904 5.6175 -181.21
# - adjclosebondlag2_return   1   0.07575 5.6442 -180.84
# - adjclosebondlag4_return   1   0.08551 5.6539 -180.70
# - volumelag3_return         1   0.09460 5.6630 -180.57
# - adjclosebondlag6_return   1   0.10066 5.6691 -180.49
# - adjclosebondlag1_return   1   0.10251 5.6709 -180.47
# <none>                                  5.5684 -179.89
# - adjclosestock_return      1   0.18477 5.7532 -179.34
# - volumelag1_return         1   0.23056 5.7990 -178.72
# - adjclosebondlag5_return   1   0.30660 5.8750 -177.71
# - adjclosestocklag3_return  1   0.36420 5.9326 -176.95
# - adjclosebondlag3_return   1   0.36663 5.9350 -176.91
#
# Step:  AIC=-181.64
# grade10price_return ~ adjclosestock_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosebondlag4_return + adjclosebondlag5_return + adjclosestocklag6_return +
#     adjclosebondlag6_return + volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestocklag6_return  1   0.05615 5.6427 -182.86
# - adjclosebondlag4_return   1   0.08005 5.6666 -182.53
# - volumelag3_return         1   0.08201 5.6685 -182.50
# - adjclosebondlag6_return   1   0.08917 5.6757 -182.40
# - adjclosebondlag2_return   1   0.09541 5.6819 -182.31
# - adjclosebondlag1_return   1   0.10872 5.6952 -182.13
# <none>                                  5.5865 -181.64
# - adjclosestock_return      1   0.16798 5.7545 -181.32
# - volumelag1_return         1   0.21653 5.8030 -180.67
# - adjclosebondlag5_return   1   0.30791 5.8944 -179.45
# - adjclosestocklag3_return  1   0.34862 5.9351 -178.91
# - adjclosebondlag3_return   1   0.37572 5.9622 -178.56
#
# Step:  AIC=-182.86
# grade10price_return ~ adjclosestock_return + adjclosebondlag1_return +
#     adjclosebondlag2_return + adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosebondlag4_return + adjclosebondlag5_return + adjclosebondlag6_return +
#     volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag2_return   1   0.08171 5.7244 -183.73
# - volumelag3_return         1   0.09175 5.7344 -183.60
# - adjclosebondlag6_return   1   0.09197 5.7346 -183.59
# - adjclosebondlag4_return   1   0.09537 5.7380 -183.55
# - adjclosebondlag1_return   1   0.10198 5.7446 -183.46
# <none>                                  5.6427 -182.86
# - adjclosestock_return      1   0.19190 5.8345 -182.25
# - volumelag1_return         1   0.20424 5.8469 -182.08
# - adjclosebondlag5_return   1   0.28378 5.9264 -181.03
# - adjclosebondlag3_return   1   0.35903 6.0017 -180.04
# - adjclosestocklag3_return  1   0.37152 6.0142 -179.88
#
# Step:  AIC=-183.73
# grade10price_return ~ adjclosestock_return + adjclosebondlag1_return +
#     adjclosestocklag3_return + adjclosebondlag3_return + adjclosebondlag4_return +
#     adjclosebondlag5_return + adjclosebondlag6_return + volumelag1_return +
#     volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag1_return   1   0.07274 5.7971 -184.75
# - adjclosebondlag6_return   1   0.07732 5.8017 -184.69
# - volumelag3_return         1   0.08660 5.8110 -184.56
# - adjclosebondlag4_return   1   0.09008 5.8144 -184.52
# <none>                                  5.7244 -183.73
# - volumelag1_return         1   0.17813 5.9025 -183.34
# - adjclosestock_return      1   0.19257 5.9169 -183.15
# - adjclosebondlag5_return   1   0.28258 6.0069 -181.98
# - adjclosebondlag3_return   1   0.31206 6.0364 -181.59
# - adjclosestocklag3_return  1   0.40233 6.1267 -180.44
#
# Step:  AIC=-184.75
# grade10price_return ~ adjclosestock_return + adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag4_return + adjclosebondlag5_return +
#     adjclosebondlag6_return + volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag6_return   1   0.06155 5.8587 -185.93
# - volumelag3_return         1   0.08487 5.8820 -185.62
# - adjclosebondlag4_return   1   0.08758 5.8847 -185.58
# <none>                                  5.7971 -184.75
# - volumelag1_return         1   0.15853 5.9556 -184.65
# - adjclosestock_return      1   0.18446 5.9816 -184.31
# - adjclosebondlag5_return   1   0.26019 6.0573 -183.32
# - adjclosebondlag3_return   1   0.33062 6.1277 -182.42
# - adjclosestocklag3_return  1   0.41955 6.2167 -181.30
#
# Step:  AIC=-185.93
# grade10price_return ~ adjclosestock_return + adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag4_return + adjclosebondlag5_return +
#     volumelag1_return + volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosebondlag4_return   1   0.08870 5.9474 -186.75
# - volumelag3_return         1   0.09812 5.9568 -186.63
# <none>                                  5.8587 -185.93
# - adjclosestock_return      1   0.15649 6.0151 -185.87
# - volumelag1_return         1   0.15855 6.0172 -185.84
# - adjclosebondlag5_return   1   0.21349 6.0721 -185.13
# - adjclosebondlag3_return   1   0.32642 6.1851 -183.70
# - adjclosestocklag3_return  1   0.40737 6.2660 -182.68
#
# Step:  AIC=-186.75
# grade10price_return ~ adjclosestock_return + adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return +
#     volumelag3_return
#
#                            Df Sum of Sq    RSS     AIC
# - volumelag3_return         1   0.07473 6.0221 -187.78
# - adjclosestock_return      1   0.13342 6.0808 -187.02
# <none>                                  5.9474 -186.75
# - volumelag1_return         1   0.18404 6.1314 -186.38
# - adjclosebondlag5_return   1   0.28576 6.2331 -185.09
# - adjclosestocklag3_return  1   0.40990 6.3573 -183.56
# - adjclosebondlag3_return   1   0.42500 6.3724 -183.37
#
# Step:  AIC=-187.78
# grade10price_return ~ adjclosestock_return + adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return
#
#                            Df Sum of Sq    RSS     AIC
# - adjclosestock_return      1   0.14414 6.1662 -187.94
# <none>                                  6.0221 -187.78
# - volumelag1_return         1   0.18442 6.2065 -187.43
# - adjclosestocklag3_return  1   0.33678 6.3589 -185.53
# - adjclosebondlag5_return   1   0.35424 6.3763 -185.32
# - adjclosebondlag3_return   1   0.46208 6.4842 -184.01
#
# Step:  AIC=-187.93
# grade10price_return ~ adjclosestocklag3_return + adjclosebondlag3_return +
#     adjclosebondlag5_return + volumelag1_return
#
#                            Df Sum of Sq    RSS     AIC
# <none>                                  6.1662 -187.94
# - volumelag1_return         1   0.20169 6.3679 -187.42
# - adjclosebondlag5_return   1   0.29489 6.4611 -186.29
# - adjclosestocklag3_return  1   0.31810 6.4843 -186.01
# - adjclosebondlag3_return   1   0.44999 6.6162 -184.44
# Call:
# lm(formula = grade10price_return ~ adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return,
#     data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85089 -0.15132 -0.03192  0.13011  0.80810
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               0.02880    0.03348   0.860   0.3926
# adjclosestocklag3_return  1.34665    0.69394   1.941   0.0562 .
# adjclosebondlag3_return  -0.88322    0.38266  -2.308   0.0238 *
# adjclosebondlag5_return  -0.69941    0.37433  -1.868   0.0657 .
# volumelag1_return        -0.32745    0.21191  -1.545   0.1266
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2906 on 73 degrees of freedom
# Multiple R-squared:  0.1561,	Adjusted R-squared:  0.1099
# F-statistic: 3.376 on 4 and 73 DF,  p-value: 0.01366

# %% [markdown]
# ## Models

# %% [markdown]
# ### OLS

# %%
#OLS
ols_model <- lm(grade10price_return ~ adjclosestocklag3_return + 
    adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return, data = df) 

print(summary(ols_model))

library(car)

# Calculate VIF
vif_result <- vif(ols_model)
print(vif_result)

library(lmtest)

# Perform the Breusch-Pagan test
bp_test <- bptest(ols_model)

# Print the test results
print(bp_test)
# Out:
# Call:
# lm(formula = grade10price_return ~ adjclosestocklag3_return +
#     adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return,
#     data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85089 -0.15132 -0.03192  0.13011  0.80810
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               0.02880    0.03348   0.860   0.3926
# adjclosestocklag3_return  1.34665    0.69394   1.941   0.0562 .
# adjclosebondlag3_return  -0.88322    0.38266  -2.308   0.0238 *
# adjclosebondlag5_return  -0.69941    0.37433  -1.868   0.0657 .
# volumelag1_return        -0.32745    0.21191  -1.545   0.1266
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2906 on 73 degrees of freedom
# Multiple R-squared:  0.1561,	Adjusted R-squared:  0.1099
# F-statistic: 3.376 on 4 and 73 DF,  p-value: 0.01366
#
# adjclosestocklag3_return  adjclosebondlag3_return  adjclosebondlag5_return
#                 1.014053                 1.034609                 1.002958
#        volumelag1_return
#                 1.041955
#
# 	studentized Breusch-Pagan test
#
# data:  ols_model
# BP = 1.5619, df = 4, p-value = 0.8156

# %% [markdown]
# No heteroskedasticity nor multicollinearity

# %% [markdown]
# ### Quantile regression

# %%
#Quantile regression
library(quantreg)

quantile_model <- rq(grade10price_return ~ adjclosestocklag3_return + 
    adjclosebondlag3_return + adjclosebondlag5_return + volumelag1_return, data = df, tau = seq(from=0.05, to=0.95, by=0.05))  #change tau for different quantiles
                                                                                                                                   

#print summary of quantile regression models
for(grade_return in grade_returns) {
  #print(paste("Summary of quantile regression model for:", grade_return))
  #print(summary(quantile_models[[grade_return]]))
}

#uncomment the last two commented rows (in the previous loop) if you want to see the results for quantiles from 0.05 to 0.95, by 0.05 step

# %% [markdown]
# #### Results for different quantiles of the grade 10 prices x OLS estimates (red line)

# %%
plot(summary(quantile_model))
# Out:
# Plot with title "volumelag1_return"
